# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Web Scraping
#
# _Author: Dave Yerrington (SF)_
#
# ---

# %% [markdown]
# ## Before Class
#
# #### Install Selenium
#
# Selenium is a headless browser. It allows us to render JavaScript just as a human-navigated browser would.
#
# To install Selenium, use one of the following:
# - **Anaconda:** `conda install -c conda-forge selenium`
# - **pip:** `pip install selenium`
#
#
# #### Install GeckoDriver
#
# You will also need GeckoDriver (this assumes you are using Homebrew for Mac):
#
# - ```brew install geckodriver```
#
# #### Install Firefox
#
# Additionally, you will need to have downloaded the [Firefox browser](https://www.mozilla.org/en-US/firefox/new/?utm_source=google&utm_medium=cpc&utm_campaign=Firefox-Brand-US-GGL-Exact&utm_term=firefox&utm_content=A144_A203_A006336&gclid=Cj0KEQjwnPLKBRC-j7nt1b7OlZwBEiQAv8lMLJUyReT6cPzSYdmEA6uD3YDoieuuuusddgAU7XH6smEaAoje8P8HAQ&gclsrc=aw.ds) for the application in this lesson.

# %% [markdown]
# ## Learning Objectives
# - Revisit how to locate elements on a webpage
# - Aquire unstructure data from the internet using Beautiful soup.
# - Discuss limitations associated with simple requests and urllib libraries
# - Introduce Selenium as a solution, and implement a scraper using selenium

# %% [markdown]
# ## Lesson Guide
#
# - [Introduction](#intro)
# - [Building a web scraper](#building-scraper)
# - [Retrieving data from the HTML page](#retrieving-data)
#     - [Retrieving the restaurant names](#retrieving-names)
#     - [Challenge: Retrieving the restaurant locations](#retrieving-locations)
#     - [Retrieving the restaurant prices](#retrieving-prices)
#     - [Retrieving the restaurant number of bookings](#retrieving-bookings)
#
#
# - [Introducting Selenium](#selenium)
#     - [Running JavaScript before scraping](#selenium-js)
#     - [Using regex to only get digits](#selenium-regex)
#     - [Challenge: Use Pandas to create a DataFrame of bookings](#challenge-pandas)
#     - [Auto-typing using Selenium](#selenium-typing)
#
#
# - [Summary](#summary)

# %% [markdown]
# <a id="intro"></a>
# ## Introduction
#
# In this codealong lesson, we'll build a web scraper using urllib and BeautifulSoup. We will also explore how to use a headless browser called Selenium.
#
# We'll begin by scraping OpenTable's DC listings. We're interested in knowing the restaurant's **name, location, price, and how many people booked it today.**
#
# OpenTable provides all of this information on this given page: http://www.opentable.com/washington-dc-restaurant-listings
#
# Let's inspect the elements of this page to assure we can find each of the bits of information in which we're interested.
#
# ---

# %% [markdown]
# <a id="building-scraper"></a>
# ## Building a web scraper
#
# Now, let's build a web scraper for OpenTable using urllib and Beautiful Soup:

# %%
# import our necessary first packages
from bs4 import BeautifulSoup
import requests

# %%
# set the url we want to visit
url = "http://www.opentable.com/washington-dc-restaurant-listings"

# visit that url, and grab the html of said page
html = requests.get(url)

# %% [markdown]
# At this point, what is in html?

# %%
# .text returns the request content in Unicode
html.text[:500]

#printing the first 500 characters
# Out:
# '           <!DOCTYPE html><html lang="en"><head><meta charset="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=9; IE=8; IE=7; IE=EDGE"/> <title>Restaurant Reservation Availability</title>    <meta  name="robots" content="noindex,nofollow" > </meta>     <link rel="shortcut icon" href="//components.otstatic.com/components/favicon/1.0.6/favicon/favicon.ico" type="image/x-icon"/><link rel="icon" href="//components.otstatic.com/components/favicon/1.0.6/favicon/favicon-16.png" sizes="16x16"/><l'

# %% [markdown]
# We will need to convert this html objct into a soup object so we can parse it using python and BS4

# %%
# convert this into a soup object
soup = BeautifulSoup(html.text, 'html.parser')

# %% [markdown]
# <a id="retrieving-data"></a>
# ### Retrieving data from the HTML page

# %% [markdown]
# Let's first find each restaurant name listed on the page we've loaded. How do we find the page location of the restaurant? (Hint: We need to know where in the **HTML** the restaurant element is housed.) In order to find the HTML that renders the restaurant location, we can use Google Chrome's Inspect tool:
#
# > http://www.opentable.com/washington-dc-restaurant-listings
#
# > 1. Visit the URL above.
#
# > 2. Right-click on an element you are interested in, then choose Inspect (in Chrome).
#
# > 3. This will open the Developer Tools and show the HTML used to render the selected page element.
#
# > Throughout this lesson, we will use this method to find tags associated with elements of the page we want to scrape.
#
# See if you can find the restaurant name on the page. Keep in mind there are many restaurants loaded on the page.

# %%
# print the restaurant names
soup.find_all(name='span', attrs={'class':'rest-row-name-text'})

#name of the html tag, and extra attributes
# Out:
# [<span class="rest-row-name-text">Durward Ziemann</span>,
#  <span class="rest-row-name-text">Cales</span>,
#  <span class="rest-row-name-text">Caroline Bergnaum</span>,
#  <span class="rest-row-name-text">Et Bailey</span>,
#  <span class="rest-row-name-text">Id</span>,
#  <span class="rest-row-name-text">Nayeli Bartoletti</span>,
#  <span class="rest-row-name-text">Fernes</span>,
#  <span class="rest-row-name-text">Agloe Bar &amp; Grill</span>,
#  <span class="rest-row-name-text">1138 Rippin</span>,
#  <span class="rest-row-name-text">Glover</span>,
#  <span class="rest-row-name-text">Ernestos</span>,
#  <span class="rest-row-name-text">Centers</span>,
#  <span class="rest-row-name-text">Omnis Heaney</span>,
#  <span class="rest-row-name-text">Streich Ridge</span>,
#  <span class="rest-row-name-text">Vincent Mission</span>,
#  <span class="rest-row-name-text">Harum Roob</span>,
#  <span class="rest-row-name-text">Mount</span>,
#  <span class="rest-row-name-text">Et Route</span>,
#  <span class="rest-row-name-text">1152 Wyman</span>,
#  <span class="rest-row-name-text">Bosco Fords</span>,
#  <span class="rest-row-name-text">1113 DuBuque</span>,
#  <span class="rest-row-name-text">Et</span>,
#  <span class="rest-row-name-text">Vel Schaefer</span>,
#  <span class="rest-row-name-text">Qui Dicki</span>,
#  <span class="rest-row-name-text">Florida Wells</span>,
#  <span class="rest-row-name-text">Squares</span>,
#  <span class="rest-row-name-text">Alexandro Ankunding</span>,
#  <span class="rest-row-name-text">Jannie Johns</span>,
#  <span class="rest-row-name-text">Dolor</span>,
#  <span class="rest-row-name-text">Kianas</span>,
#  <span class="rest-row-name-text">1324 Gerlach</span>,
#  <span class="rest-row-name-text">Inventore Gateway</span>,
#  <span class="rest-row-name-text">Island</span>,
#  <span class="rest-row-name-text">Sunt</span>,
#  <span class="rest-row-name-text">643 Bode</span>,
#  <span class="rest-row-name-text">Overpass</span>,
#  <span class="rest-row-name-text">Est Cliffs</span>,
#  <span class="rest-row-name-text">Radial</span>,
#  <span class="rest-row-name-text">Dicta</span>,
#  <span class="rest-row-name-text">Johnny Will</span>,
#  <span class="rest-row-name-text">Alaniss</span>,
#  <span class="rest-row-name-text">Oberbrunner Village</span>,
#  <span class="rest-row-name-text">Euna Tunnel</span>,
#  <span class="rest-row-name-text">Explicabo</span>,
#  <span class="rest-row-name-text">789 Rice</span>,
#  <span class="rest-row-name-text">1133 Hayes</span>,
#  <span class="rest-row-name-text">Dolor</span>,
#  <span class="rest-row-name-text">Recusandae Treutel</span>,
#  <span class="rest-row-name-text">Tevins</span>,
#  <span class="rest-row-name-text">Herman Junction</span>,
#  <span class="rest-row-name-text">Vel</span>,
#  <span class="rest-row-name-text">567 Rutherford</span>,
#  <span class="rest-row-name-text">Mustafa Dam</span>,
#  <span class="rest-row-name-text">Court</span>,
#  <span class="rest-row-name-text">Nulla Abshire</span>,
#  <span class="rest-row-name-text">Stream</span>,
#  <span class="rest-row-name-text">Ville</span>,
#  <span class="rest-row-name-text">Non Village</span>,
#  <span class="rest-row-name-text">Harum</span>,
#  <span class="rest-row-name-text">Trycia Walk</span>,
#  <span class="rest-row-name-text">Chyna Graham</span>,
#  <span class="rest-row-name-text">White</span>,
#  <span class="rest-row-name-text">At Lemke</span>,
#  <span class="rest-row-name-text">Adipisci Bednar</span>,
#  <span class="rest-row-name-text">Fuga Bergnaum</span>,
#  <span class="rest-row-name-text">Odit Pines</span>,
#  <span class="rest-row-name-text">Hayes</span>,
#  <span class="rest-row-name-text">Beatae Mertz</span>,
#  <span class="rest-row-name-text">Lexi O'Keefe</span>,
#  <span class="rest-row-name-text">Occaecati Gaylord</span>,
#  <span class="rest-row-name-text">Birdie McGlynn</span>,
#  <span class="rest-row-name-text">Non Lakin</span>,
#  <span class="rest-row-name-text">Sit Howe</span>,
#  <span class="rest-row-name-text">Quis Hyatt</span>,
#  <span class="rest-row-name-text">Et</span>,
#  <span class="rest-row-name-text">Vitae Paucek</span>,
#  <span class="rest-row-name-text">Mann</span>,
#  <span class="rest-row-name-text">Gerhard Koch</span>,
#  <span class="rest-row-name-text">Ducimus Lodge</span>,
#  <span class="rest-row-name-text">Brekke Cape</span>,
#  <span class="rest-row-name-text">409 Corkery</span>,
#  <span class="rest-row-name-text">Kunde</span>,
#  <span class="rest-row-name-text">Landing</span>,
#  <span class="rest-row-name-text">Okuneva</span>,
#  <span class="rest-row-name-text">Bergnaum</span>,
#  <span class="rest-row-name-text">Lueilwitz</span>,
#  <span class="rest-row-name-text">Elizabeth Hartmann</span>,
#  <span class="rest-row-name-text">Daniel</span>,
#  <span class="rest-row-name-text">Ferne Parisian</span>,
#  <span class="rest-row-name-text">Canyon</span>,
#  <span class="rest-row-name-text">Chance Lebsack</span>,
#  <span class="rest-row-name-text">Bogisich</span>,
#  <span class="rest-row-name-text">Ezekiel Pollich</span>,
#  <span class="rest-row-name-text">Itaque Kuphal</span>,
#  <span class="rest-row-name-text">Et Islands</span>,
#  <span class="rest-row-name-text">Inlet</span>,
#  <span class="rest-row-name-text">Sapiente</span>,
#  <span class="rest-row-name-text">Commodi Terrace</span>,
#  <span class="rest-row-name-text">Quam Predovic</span>,
#  <span class="rest-row-name-text">Geoffrey O'Hara</span>]

# %% [markdown]
# It is important to always keep in mind the data types that were returned. Note this is a `list`, and we know that immediately by observing the outer square brackets and commas separating each tag.
#
# Next, note the elements of the list are `Tag` objects, not strings. (If they were strings, they would be surrounded by quotes.) The Beautiful Soup authors chose to display a `Tag` object visually as a text representation of the tag and its contents. However, being an object, it has many methods that we can call on it. For example, next we will use the `encode_contents()` method to return the tag's contents encoded as a Python string.
#
# <a id="retrieving-names"></a>
# #### Retrieving the restaurant names
#
# Now that we found a list of tags containing the restaurant names, let's think how we can loop through them all one-by-one. In the following cell, we'll print out the name (and **only** the clean name, not the rest of the html) of each restaurant.

# %%
# for each element you find, print out the restaurant name
for entry in soup.find_all(name='span', attrs={'class':'rest-row-name-text'}):
    print(entry.text)
# Out:
# Durward Ziemann
# Cales
# Caroline Bergnaum
# Et Bailey
# Id
# Nayeli Bartoletti
# Fernes
# Agloe Bar & Grill
# 1138 Rippin
# Glover
# Ernestos
# Centers
# Omnis Heaney
# Streich Ridge
# Vincent Mission
# Harum Roob
# Mount
# Et Route
# 1152 Wyman
# Bosco Fords
# 1113 DuBuque
# Et
# Vel Schaefer
# Qui Dicki
# Florida Wells
# Squares
# Alexandro Ankunding
# Jannie Johns
# Dolor
# Kianas
# 1324 Gerlach
# Inventore Gateway
# Island
# Sunt
# 643 Bode
# Overpass
# Est Cliffs
# Radial
# Dicta
# Johnny Will
# Alaniss
# Oberbrunner Village
# Euna Tunnel
# Explicabo
# 789 Rice
# 1133 Hayes
# Dolor
# Recusandae Treutel
# Tevins
# Herman Junction
# Vel
# 567 Rutherford
# Mustafa Dam
# Court
# Nulla Abshire
# Stream
# Ville
# Non Village
# Harum
# Trycia Walk
# Chyna Graham
# White
# At Lemke
# Adipisci Bednar
# Fuga Bergnaum
# Odit Pines
# Hayes
# Beatae Mertz
# Lexi O'Keefe
# Occaecati Gaylord
# Birdie McGlynn
# Non Lakin
# Sit Howe
# Quis Hyatt
# Et
# Vitae Paucek
# Mann
# Gerhard Koch
# Ducimus Lodge
# Brekke Cape
# 409 Corkery
# Kunde
# Landing
# Okuneva
# Bergnaum
# Lueilwitz
# Elizabeth Hartmann
# Daniel
# Ferne Parisian
# Canyon
# Chance Lebsack
# Bogisich
# Ezekiel Pollich
# Itaque Kuphal
# Et Islands
# Inlet
# Sapiente
# Commodi Terrace
# Quam Predovic
# Geoffrey O'Hara

# %% [markdown]
# Great!
#
# <a id="retrieving-locations"></a>
# #### Challenge: Retrieving the restaurant locations
#
# Can you repeat that process for finding the location? For example, barmini by Jose Andres is in the location listed as "Penn Quarter" in our search results.

# %%
# first, see if you can identify the location for all elements -- print it out
soup.find_all('span', {'class':'rest-row-meta--location rest-row-meta-text'})
# Out:
# [<span class="rest-row-meta--location rest-row-meta-text">South Mathew</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Darianstad</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">North Jovanimouth</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">New Jean</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Greysonfort</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Lake Amirbury</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Wolffmouth</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Murrayfurt</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">West Erynfurt</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">West Simone</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Lake Hans</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Braulioside</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">South Clay</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Turnerland</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Port Aracelyburgh</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Mrazland</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Kleinton</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">New Chaim</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">East Keira</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">South Prince</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Victoriaburgh</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Toyfurt</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">North Jaycee</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Stephonstad</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Carmellafort</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Lake Juliaborough</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Wisokytown</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Port Travonview</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Juddview</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Jaydeview</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Lake Alvisport</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Lake Bernhardfurt</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Mertzside</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Gerardohaven</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Gaybury</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Alland</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">North Madaline</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Lake Lacyhaven</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Kirstinmouth</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Angelitachester</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Cadeside</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Weimannfurt</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">New Amarashire</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">East Kielfurt</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">South Alexaneview</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Port Winona</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">East Rachelle</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Runolfsdottirport</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">New Karinaview</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Domingotown</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Port Steveshire</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Handburgh</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Eastonmouth</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Dickimouth</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">South Ashtynport</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Vandervortmouth</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Grimesfort</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">O'Connershire</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Vonbury</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">West Viviane</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Port Charles</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Kochhaven</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Lake Elnoraberg</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Lake Arden</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Port Duaneside</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Dickiborough</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Oswaldoland</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Buckmouth</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Bodeview</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Barrowstown</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">East Daphneville</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Johnathonshire</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Elsieland</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">New Kenyattafurt</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Wisokyfort</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Augustinebury</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Reynoldschester</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Hobartport</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Lake Fabianside</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Meredithbury</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Mertzberg</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">South Bobby</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Jayceeville</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">West Lulu</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Berneicebury</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">West Mohammad</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Anitaburgh</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">South Raystad</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Lake Neomatown</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Wisokyshire</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">New Mathias</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">New Raphaelle</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Grahamside</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Elsiestad</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Lake Sunny</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Funkfurt</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">South Monserrat</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Elizafort</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">West Alice</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">West Baileyburgh</span>]

# %%
# now print out EACH location for the restaurants
for entry in soup.find_all('span', {'class':'rest-row-meta--location rest-row-meta-text'}):
    print(entry.text)
# Out:
# South Mathew
# Darianstad
# North Jovanimouth
# New Jean
# Greysonfort
# Lake Amirbury
# Wolffmouth
# Murrayfurt
# West Erynfurt
# West Simone
# Lake Hans
# Braulioside
# South Clay
# Turnerland
# Port Aracelyburgh
# Mrazland
# Kleinton
# New Chaim
# East Keira
# South Prince
# Victoriaburgh
# Toyfurt
# North Jaycee
# Stephonstad
# Carmellafort
# Lake Juliaborough
# Wisokytown
# Port Travonview
# Juddview
# Jaydeview
# Lake Alvisport
# Lake Bernhardfurt
# Mertzside
# Gerardohaven
# Gaybury
# Alland
# North Madaline
# Lake Lacyhaven
# Kirstinmouth
# Angelitachester
# Cadeside
# Weimannfurt
# New Amarashire
# East Kielfurt
# South Alexaneview
# Port Winona
# East Rachelle
# Runolfsdottirport
# New Karinaview
# Domingotown
# Port Steveshire
# Handburgh
# Eastonmouth
# Dickimouth
# South Ashtynport
# Vandervortmouth
# Grimesfort
# O'Connershire
# Vonbury
# West Viviane
# Port Charles
# Kochhaven
# Lake Elnoraberg
# Lake Arden
# Port Duaneside
# Dickiborough
# Oswaldoland
# Buckmouth
# Bodeview
# Barrowstown
# East Daphneville
# Johnathonshire
# Elsieland
# New Kenyattafurt
# Wisokyfort
# Augustinebury
# Reynoldschester
# Hobartport
# Lake Fabianside
# Meredithbury
# Mertzberg
# South Bobby
# Jayceeville
# West Lulu
# Berneicebury
# West Mohammad
# Anitaburgh
# South Raystad
# Lake Neomatown
# Wisokyshire
# New Mathias
# New Raphaelle
# Grahamside
# Elsiestad
# Lake Sunny
# Funkfurt
# South Monserrat
# Elizafort
# West Alice
# West Baileyburgh

# %% [markdown]
# <a id="retrieving-prices"></a>
# #### Retrieving the restaurant prices

# %% [markdown]
# Ok, we've figured out the restaurant name and location. Now we need to grab the price (number of dollar signs on a scale of one to four) for each restaurant. We'll follow the same process.

# %%
# print out all prices
soup.find_all('div', {'class':'rest-row-pricing'})
# Out:
# [<div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>]

# %%
# print out EACH number of dollar signs per restaurant
# this one is trickier to eliminate the html. Hint: try a nested find
for entry in soup.find_all('div', {'class':'rest-row-pricing'}):
    print(entry.find('i').text)
# Out:
#   $    $
#   $    $    $    $
#   $    $    $    $
#   $    $    $    $
#   $    $    $    $
#   $    $    $    $
#   $    $    $    $
#   $    $
#   $    $    $    $
#   $    $    $
#   $    $    $    $
#   $    $    $    $
#   $    $    $    $
#   $    $
#   $    $    $    $
#   $    $    $    $
#   $    $    $
#   $    $    $
#   $    $    $    $
#   $    $
#   $    $    $
#   $    $
#   $    $    $    $
#   $    $    $    $
#   $    $    $
#   $    $    $
#   $    $
#   $    $    $    $
#   $    $
#   $    $    $    $
#   $    $    $    $
#   $    $    $    $
#   $    $    $
#   $    $    $
#   $    $    $
#   $    $    $
#   $    $
#   $    $    $
#   $    $    $
#   $    $    $
#   $    $    $
#   $    $    $    $
#   $    $    $
#   $    $    $
#   $    $    $    $
#   $    $
#   $    $    $
#   $    $    $
#   $    $    $    $
#   $    $    $
#   $    $
#   $    $    $    $
#   $    $    $    $
#   $    $    $    $
#   $    $    $
#   $    $    $    $
#   $    $
#   $    $    $
#   $    $
#   $    $    $    $
#   $    $    $
#   $    $
#   $    $    $    $
#   $    $
#   $    $
#   $    $    $
#   $    $    $    $
#   $    $    $    $
#   $    $
#   $    $    $
#   $    $
#   $    $    $    $
#   $    $    $
#   $    $
#   $    $
#   $    $    $
#   $    $    $
#   $    $
#   $    $
#   $    $    $    $
#   $    $    $    $
#   $    $    $
#   $    $    $
#   $    $    $    $
#   $    $
#   $    $    $
#   $    $    $    $
#   $    $    $
#   $    $    $    $
#   $    $
#   $    $
#   $    $    $
#   $    $
#   $    $    $
#   $    $    $
#   $    $    $    $
#   $    $    $
#   $    $    $
#   $    $    $
#   $    $    $    $

# %% [markdown]
# That looks great, but what if I wanted just the number of dollar signs per restaurant? Can you figure out a way to simply print out the number of dollar signs per restaurant listed?

# %%
# print the number of dollars signs per restaurant
for entry in soup.find_all('div', {'class':'rest-row-pricing'}):
    price = entry.find('i').text
    print(price.count('$'))
# Out:
# 2
# 4
# 4
# 4
# 4
# 4
# 4
# 2
# 4
# 3
# 4
# 4
# 4
# 2
# 4
# 4
# 3
# 3
# 4
# 2
# 3
# 2
# 4
# 4
# 3
# 3
# 2
# 4
# 2
# 4
# 4
# 4
# 3
# 3
# 3
# 3
# 2
# 3
# 3
# 3
# 3
# 4
# 3
# 3
# 4
# 2
# 3
# 3
# 4
# 3
# 2
# 4
# 4
# 4
# 3
# 4
# 2
# 3
# 2
# 4
# 3
# 2
# 4
# 2
# 2
# 3
# 4
# 4
# 2
# 3
# 2
# 4
# 3
# 2
# 2
# 3
# 3
# 2
# 2
# 4
# 4
# 3
# 3
# 4
# 2
# 3
# 4
# 3
# 4
# 2
# 2
# 3
# 2
# 3
# 3
# 4
# 3
# 3
# 3
# 4

# %% [markdown]
# Phew, nice work.
#
# <a id="retrieving-bookings"></a>
# #### Retrieving the restaurant number of bookings
#
# One more, right? We only need to find the number times a restaurant was booked. In the next cell, print out all objects that contain the number of times the restaurant was booked.

# %%
# print out all objects that contain the number of times the restaurant was booked
soup.find_all('div', {'class':'booking'})
# Out:
# []

# %% [markdown]
# That's weird -- an empty set. Did we find the wrong element? What's going on here? Discuss.
#
# How can we debug this? Any ideas?

# %%
# let's first try printing out all 'div' objects
#  NOTE: This is a too many objects to store in this notebook!
#        So, uncomment the code below to run it.

for entry in soup.find_all('div'):
    print(entry)
# Out:
# <div class="master-container" id="search-master-container"> <script>
#   if (window.Cypress) {
#     window.__TestGaCalls = [];
#     window.MapTrackGA = function(dataPoint) {
#       window.ga = function(_) {
#         window.__TestGaCalls.push(arguments);
#       }
#       var data = {};
#       data[dataPoint] = '1';
#       ga('gtm1.send', 'event', 'map_event', 'map_event', data);
#     }
#   }
#   else {
#     window.MapTrackGA = function(dataPoint) {
#       if (typeof ga === 'function') {
#         var data = {};
#         data[dataPoint] = '1';
#         ga('gtm1.send', 'event', 'map_event', 'map_event', data);
#       }
#     }
#   }
# </script> <style>.icon-font{font-family:icons;speak:none;font-style:normal;font-weight:400;font-variant:normal;text-transform:none;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.breadcrumb li.icon-visible a:before{font-family:icons;speak:none;font-style:normal;font-weight:400;font-variant:normal;text-transform:none;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.breadcrumb{background-color:#fff!important;height:2rem;line-height:1.9rem;font-size:.75rem;border-top:1px solid rgba(0,0,0,.08)!important;border-bottom:none!important;padding:0 1.25rem}.breadcrumb:after,.breadcrumb:before{content:" ";display:table}.breadcrumb:after{clear:both}@media only screen and (min-width:64.0625em){.breadcrumb{padding:0 2.25rem}}.breadcrumb li{position:relative;display:block;float:left;margin:0 1rem 0 .35rem}.breadcrumb li.hidden{display:none}@media only screen and (min-width:40.0625em){.breadcrumb li.hidden{display:block}}.breadcrumb li.icon-visible{margin-left:0;height:100%;width:1.25rem}@media only screen and (min-width:40.0625em){.breadcrumb li.icon-visible{margin-left:.35rem;width:auto}}.breadcrumb li.icon-visible a{display:block;width:100%;height:100%}.breadcrumb li.icon-visible a span{display:none}@media only screen and (min-width:40.0625em){.breadcrumb li.icon-visible a span{display:block}}.breadcrumb li.icon-visible a:before{content:"a";display:block;width:1.5rem;height:2rem;line-height:2rem;text-align:center;position:absolute;font-size:1rem}@media only screen and (min-width:40.0625em){.breadcrumb li.icon-visible a:before{display:none}}.breadcrumb li:first-child{margin-left:0}.breadcrumb li:last-child{margin-right:0}.breadcrumb li:last-child:after,.breadcrumb li:last-child:before{display:none}.breadcrumb li:after,.breadcrumb li:before{content:'';position:absolute;left:100%;margin-left:.25rem}.breadcrumb li:before{top:-1px;border-top:1rem solid transparent;border-bottom:1rem solid transparent;border-left:.6rem solid rgba(0,0,0,.2)}.breadcrumb li:after{top:0;border-top:.96rem solid transparent;border-bottom:.96rem solid transparent;border-left:.56rem solid #fff}.domain-comau .top-bar-nav-link.icon-location{line-height:55px}.domain-comau .top-bar-nav-link.icon-location:before{color:rgba(0,0,0,.12);font-size:18px;position:relative;top:4px;left:-2px}.domain-comau .with-location-picker .tab-bar-logo{margin-left:48px}.domain-comau .hamburger-menu .top-bar-nav-link{line-height:50px}.menu-drawer-left.sliding-menu .menu-close:after{font-family:icons;speak:none;font-style:normal;font-weight:400;font-variant:normal;text-transform:none;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.menu-drawer-left.sliding-menu{position:fixed;background-color:unset;top:0;left:0;width:100%;height:100%;pointer-events:none;transition:background-color .25s ease-out}.menu-drawer-left.sliding-menu.menu-opened{background-color:rgba(0,0,0,.5);pointer-events:auto}.menu-drawer-left.sliding-menu.menu-opened:before{content:none}.menu-drawer-left.sliding-menu.menu-opened .menu-container{transform:translate3d(0,0,0)}.menu-drawer-left.sliding-menu .menu-container{width:220px;height:100%;max-height:initial;transition:transform .5s ease-out;transform:translate3d(-220px,0,0);opacity:1}.menu-drawer-left.sliding-menu .menu-container .menu-main{border-radius:0;box-shadow:none;width:100%;height:100%;margin:0;padding:3rem 0 .25rem 0}.menu-drawer-left.sliding-menu .menu-list-link{transition:color .15s ease-out;font-size:.875rem;padding:.5rem 1rem .5rem 1.5rem}.menu-drawer-left.sliding-menu .menu-list-link-primary{color:#60b2d0!important;border-bottom:1px solid rgba(0,0,0,.08);font-size:1rem;padding:.75rem 1rem .75rem 1.5rem}.menu-drawer-left.sliding-menu .menu-list-link-primary:hover{color:#356273!important}.menu-drawer-left.sliding-menu .menu-list-link-primary.sign-out-link{color:#da3743!important}.menu-drawer-left.sliding-menu .menu-list-link-primary.sign-out-link:hover{color:#8115 ...
# </script><script>window.abtestGoalTracked = {};
# window.displaySearchFormHeader = false
# window.trackGoal = function trackGoal(goalName) {
#   if(window.analytics) {
#     if (window.debug_abtest_tracking) { console.log('Tracking goal: ', goalName); }
#
#     window.analytics.track(
#       'track_goal',
#       { goal_name: goalName },
#       function (err) { if(err) console.log(err); }
#     );
#   }
# };
#
# window.trackGoalOnce = function trackGoalOnce(goalName) {
#   if (!window.abtestGoalTracked[goalName]) {
#     window.abtestGoalTracked[goalName] = true;
#     window.trackGoal(goalName);
#   }
# }
#
# window.pageData = window.pageData || {};
g/new-england/maine-restaurants","r":1324},{"n":"Rhode Island","m":92,"u":"/g/new-england/rhode-island-restaurants","r":1065},{"n":"Vermont","m":114,"u":"/g/new-england/vermont-restaurants","r":804},{"n":"New Hampshire","m":131,"u":"/g/new-england/new-hampshire-restaurants","r":1158}],"f":true},{"n":"Chicago / Illinois","d":"Chicago / Illinois","m":3,"cn":"United States","cid":"US","did":1,"l":"en","u":"/chicago-restaurants","r":11006,"lat":41.8779,"lon":-87.852445,"ma":[{"n":"Chicago","m":11,"u":"/i/chicago/chicago-restaurants","r":3098},{"n":"North Suburbs","m":12,"u":"/g/chicago/north-suburbs-restaurants","r":917},{"n":"West Suburbs","m":15,"u":"/g/chicago/west-suburbs-restaurants","r":1204},{"n":"Northwest Suburbs","m":107,"u":"/g/chicago/northwest-suburbs-restaurants","r":1108},{"n":"Southwest Suburbs","m":198,"u":"/g/chicago/southwest-suburbs-restaurants","r":749},{"n":"Near West","m":1429,"u":"/g/chicago/near-west-restaurants","r":323},{"n":"South Suburbs","m":13,"u":" ...
# window.pageData.metroId = 9;
# window.pageData.words = {
#   all: 'All {0}',
#   table: '',
#   usernameWelcome: 'Hello!'
# };
# window.pageData.headerSignedIn = false;
# window.forRestaurateursLink = {
#   onClick: function forRestaurateursLinkClicked() {
#     var url = 'https://restaurant.opentable.com/?utm_source=dinersite&utm_medium=referral&utm_campaign=topnav&Lead.LeadSource=DinerSite&Lead.Marketing_ID__c=topnav';
#     window.trackGoal('header_forRestaurateursLink_click');
#     window.open(url, '_blank');
#   }
# };
# window.promoBanner = {
#   onClick: function promoBannerClicked() {
#     var url = 'https://www.opentable.co.uk/promo.aspx?m=72&ref=18212&pid=11316';
#     window.trackGoal('header_londonRestaurantFestivalBanner_click');
#     window.open(url, '_blank');
#   }
# }
# </script><script>$(".breadcrumb-link").click(function(c){window.trackGoal&&window.trackGoal("breadcrumb_link_clicked")});</script><img alt="" height="0" src="https://tag.yieldoptimizer.com/ps/ps?t=i&amp;p=5816&amp;uex=D1ED25A9-053B-4477-B4E1-EC9C0C144CA9" style="display: none;" width="0"/><script>window.oc=window.oc||{};oc.renderedComponents=oc.renderedComponents||{};oc.renderedComponents["header"]="1.4.120";</script> <div class="" id="search_control_container"> <div class="labels cf" id="search_control"> <div class="page-header cf"><div class="max-width-wrapper"><div class="page-header-content"> <div class="row"><div class="column"> <oc-component data-hash="fff6ca51de789e4cc6a7f6cbc1989fcd212dc14e" data-name="dtp" data-rendered="true" data-version="1.8.7" href="https://oc-registry.opentable.com/v2/dtp/^1.6.1?twoBoxSearch=false&amp;dateTime=2019-10-12T19%3A00&amp;metroId=9&amp;partySize=2&amp;showLargerParty=true&amp;showSearch=true&amp;searchPlaceholder=Location%2C%20Restaurant%2C%20or%20Cuisine&amp;theme=com&amp;showLoader=false&amp;spotlightButton=false&amp;otKit=false&amp;eventPrefix=&amp;renderCypressDataAttributes=false"><link href="//components.otstatic.com/components/dtp/1.8.7/dist/style.css" rel="stylesheet"/><style>@media (min--moz-device-pixel-ratio: 1.5), (-o-min-device-pixel-ratio: 3 / 2), (-webkit-min-device-pixel-ratio: 1.5), (min-device-pixel-ratio: 1.5), (min-resolution: 144dpi), (min-resolution: 1.5dppx) {
#     .tt-dropdown-menu:before {
#         background-image: url('//components.otstatic.com/components/dtp/1.8.7/img/menu-arrow@2x.png') !important;
#         background-size: 100%;
#     }
# }
# </style><div class="dtp-picker hide dtp-lang-en with-search single-search" data-event-prefix="" id="dtp-picker-114"><form class="dtp-picker-form false"><input name="timezoneOffset" title="timezoneOffset" type="hidden" value="-240"/><select class="party-size-picker hide"><option value="1">1 person</option><option selected="selected" value="2">2 people</option><option value="3">3 people</option><option value="4">4 people</option><option value="5">5 people</option><option value="6">6 people</option><option value="7">7 people</option><option value="8">8 people</option><option value="9">9 people</option><option value="10">10 people</option><option value="11">11 people</option><option value="12">12 people</option><option value="13">13 people</option><option value="14">14 people</option><option value="15">15 people</option><option value="16">16 people</option><option value="17">17 people</option><option value="18">18 people</option><option value="19">19 people</option><option value="20">20 people</option><option value="21">Larger party</option></select><input class="date-picker dtp-picker-selector" title="datePicker" type="text" value="2019-10-12"/><select class="time-picker hide"><option value="00:00">12:00 AM</option><option value="00:30">12:30 AM</option><option value="01:00">1:00 AM</option><option value="01:30">1:30 AM</option><option value="02:00">2:00 AM</option><option value="02:30">2:30 AM</option><option value="03:00">3:00 AM</option><option value="03:30">3:30 AM</option><option value="04:00">4:00 AM</option><option value="04:30">4:30 AM</option><option value="05:00">5:00 AM</option><option value="05:30">5:30 AM</option><option value="06:00">6:00 AM</option><option value="06:30">6:30 AM</option><option value="07:00">7:00 AM</option><option value="07:30">7:30 AM</option><option value="08:00">8:00 AM</option><option value="08:30">8:30 AM</option><option value="09:00">9:00 AM</option><option value="09:30">9:30 AM</option><option value="10:00">10:00 AM</option><option value="10:30">10:30 AM</option><option value="11:00">11:00 AM</option><option value="11:30">11:30 AM</option><option value="12:00">12:00 PM</option><option value="12:30">12:30 PM</option><option value="13:00">1:00 PM</option><option value="13:30">1:30 PM</option><option value="14:00">2:00 PM</option><option value="14:30">2:30 PM</option><option value="15:00">3:00 PM</option><option value="15:30">3:30 PM</option><option value="16:00">4:00 PM</option><option value="16:30">4:30 PM</option><option value="17:00">5:00 PM</option><option value="17:30">5:30 PM</option><option value="18:00">6:00 PM</option><option value="18:30">6:30 PM</option><option selected="selected" value="19:00">7:00 PM</option><option value="19:30">7:30 PM</option><option value="20:00">8:00 PM</option><option value="20:30">8:30 PM</option><option value="21:00">9:00 PM</option><option value="21:30">9:30 PM</option><option value="22:00">10:00 PM</option><option value="22:30">10:30 PM</option><option value="23:00">11:00 PM</option><option value="23:30">11:30 PM</option></select><div class="dtp-picker-search-container"><div class="dtp-picker-search-icon icon-search"></div><input class="dtp-picker-search" id="dtp-search-single-box" name="searchText" placeholder="Location, Restaurant, or Cuisine" title="Location, Restaurant, or Cuisine" type="text" value=""/></div><input class="button dtp-picker-button" type="submit" value="Find a Table"/></form><script>window.OT = window.OT || {};
# window.dtp_data = { theme: 'com', lang: 'en', ocUrl: 'na-srs.opentable.com/v2/', allowYesterday: false};
# </script><script src="//components.otstatic.com/components/dtp/1.8.7/dist/dtp.js?dtpId=dtp-picker-114"></script></div><script>window.oc=window.oc||{};oc.renderedComponents=oc.renderedComponents||{};oc.renderedComponents["dtp"]="1.8.7";</script></oc-component></div></div></div></div></div></div></div> <div class="modal-container table-categories-overlay" id="table-categories-overlay"><div class="modal-close"></div><div class="modal-content"><div class="modal-content-body table-selector"><div class="content-block table-selector-content" data-select-translation="Select" data-unavailable-translation="Unavailable"><div class="table-selector-header"><h3>Please select a table type</h3></div><div class="category-rows"> <div class="category-row" data-category="default" data-standard-category="true"><div class="left category-name"> Standard</div> <a class="right button category-button" data-href-addon="&amp;st=Standard&amp;papa=&amp;tc=default" href="" target="_blank">Select</a></div> <div class="category-row" data-category="bar" data-standard-category="false"><div class="left category-name"> Bar</div> <a class="right button category-button" data-href-addon="&amp;st=Standard&amp;papa=&amp;tc=bar" href="" target="_blank">Select</a></div> <div class="category-row" data-category="counter" data-standard-category="false"><div class="left category-name"> Counter</div> <a class="right button category-button" data-href-addon="&amp;st=Standard&amp;papa=&amp;tc=counter" href="" target="_blank">Select</a></div> <div class="category-row" data-category="hightop" data-standard-category="false"><div class="left category-name"> High Top</div> <a class="right button category-button" data-href-addon="&amp;st=Standard&amp;papa=&amp;tc=highTop" href="" target="_blank">Select</a></div> <div class="category-row" data-category="outdoor" data-standard-category="false"><div class="left category-name"> Outdoor</div> <a class="right button category-button" data-href-addon="&amp;st=Standard&amp;papa=&amp;tc=outdoor" href="" target="_blank">Select</a></div> </div></div></div></div></div> <input id="_csrf" name="_csrf" type="hidden" value="Jcte5Hv7-BmV6xVci_3UgnoCzwiRUyhKyzH4"/><div class="overall-search-container" id="no-re-render-container"> <div class="filters-bar show-filter-content" id="filters-bar"><div class="max-width-wrapper js-sticky-target" id="sticker"><div class="row"><div class="column"><div class="visual_map_icon" data-view="map" role="button" tabindex="0"><div class="visual-button button"> Map</div></div> <div aria-label="filters" id="search_filters" role="search"> <ul class="filters-list"> </ul> </div></div></div></div></div> <div class="stack-selected-filters"> <div class="toggle-filter-bar"><div id="filter-toggle"><div class="filter-toggle-icon"></div> <span class="show-filter-text">Show filters</span> <span class="hide-filter-text">Hide filters</span></div></div><div class="selected-filters js-selected-filters full-width-wrapper"><div class="row"><div class="column" id="js-selected-filters-column"></div></div></div> <div aria-label="search results" class="search-results-container page-main-content max-width-wrapper" id="search_results_container" role="main"><div class="close-filters"></div> <div class="loader" id="loading_animation"><div class="spinner"></div><div aria-live="assertive" class="loader-content" id="loading_error_container"></div><span aria-live="assertive" id="loading_message" style="opacity: 0"></span></div> <div class="results-set results-table search-results" data-name="ResultsTable" id="search_results"> <div class="content-section-header"> <div class="flex-row-justify results-header"> <h3 class="results-title color-dark" id="results-title">  100 Restaurants </h3> <div class="sort-view-filters"><div class="filter-option right filter-option-sort-orders" id="sort-filters"> <label class="sort-dropdown" data-target="sort-filter-menu" id="js-sort-dropdown"><div class="sort-dropdown__container"> <input class="sort-dropdown__checkbox" i ...
#   //TODO: Integrate this into react component during rewrite.  It toggles the .rest-row-offer-link from
#   // functionally expanding to see all offers, hiding the p.rest-row-offer-link and showing
#   // a.rest-row-offer-link which changes text from "See all specials" to "Learn More >" and links to the
#   // specials section on rest profile. Ticket: https://opentable.atlassian.net/browse/SV-2558
#   $('p.rest-row-offer-link').on('click', function(event) {
#     event.preventDefault();
#     $(this).closest('.hide-more-offers').removeClass('hide-more-offers').addClass('show-more-offers');
#   });
# </script> </div><div class="results-set results-map search-results" data-name="ResultsMap" id="search_results_map"> </div> <div id="row-service-results"></div></div></div><div class="right-sidebar" id="right-sidebar"></div></div> <style>.footer-base .affiliate-logo.logo-kayak{width:91px!important}.footer-base .priceline-links{margin-top:16px}#truste_banners{position:fixed;bottom:0;width:100%;max-width:100rem;display:flex;flex-direction:column-reverse;z-index:999}#truste_banners #truste-consent-track{position:static;bottom:auto}#truste-consent-content .truste-button2,#truste-consent-content .truste-messageColumn,#truste-consent-content2 .truste-messageColumn2,#truste-consent-content2 .truste-please-note{font-family:source-sans-pro,"Source Sans Pro","Helvetica Neue",Helvetica,Arial,sans-serif}#truste-consent-content .truste-button2{display:inline-block;width:auto}#truste-consent-track,#truste-consent-track2{background:rgba(51,51,51,.95)!important;z-index:999}#truste-consent-content .truste-buttonsColumn{margin:0}#truste-consent-content .truste-messageColumn{margin:23px 0}@media screen and (min-width:1025px){#truste-consent-content .truste-messageColumn{margin:23px 15px}}.footer-link-social{float:left;margin-right:8px;margin-bottom:8px;height:24px}@media screen and (min-width:641px) and (max-width:1024px){.footer-link-social{margin-right:4px;margin-bottom:4px}}.footer-link-social svg{width:24px;height:24px}.footer-link-social .social-icon-cutout{fill:#acacac}.footer-link-social:hover .social-icon-cutout{fill:#fff}.footer-link-social:last-child{margin-right:0}.footer-block a{cursor:pointer}</style><style>.footer-base .affiliate-logo {
#   background-image: url(//components.otstatic.com/components/footer/1.0.121/img/affiliate_logos.png) !important;
# }
# </style><div class="footer-container" id="footer" role="contentinfo"><div class="max-width-wrapper"><div class="email-signup footer-content-container"></div><script>$(function(){
#   $('.email-signup').html(oc.build({
#     baseUrl: OT.SRS.ocUrl,
#     name: 'oc_component_email_signup',
#     parameters: { language: 'en-US', metroId: '9' }
#   }));
#
#   oc.renderUnloadedComponents();
# });</script><div class="footer-content-container"><div class="footer-block"><h6>Discover</h6><ul><li><a onclick="onLinkClick('https://help.opentable.com/s/article/OpenTable-Dining-Rewards?language=en_US')">Dining Rewards</a></li><li><a href="https://www.opentable.com/m/private-dining-restaurants-in-north-america/">Private Dining</a></li><li><a href="https://www.opentable.com/m/best-restaurants-in-america-for-2017/">Top 100 Restaurants</a></li><li></li><li><a onclick="onLinkClick('https://help.opentable.com/s/article/How-do-I-make-reservations-for-others-with-an-Administrative-Professional-Account-1505261764797?language=en_US')">Reserve for Others</a></li><li><a onclick="onLinkClick('https://opentable.com/nearme/all-cuisines-near-me')">Cuisines Near Me</a></li></ul></div><div class="footer-block"><h6>OpenTable</h6><ul><li><a href="https://www.opentable.com/about/">About Us</a></li><li><a onclick="onLinkClick('https://blog.opentable.com')">Blog</a></li><li><a href="https://www.opentable.com/careers/">Careers</a></li><li><a onclick="onLinkClick('http://press.opentable.com')">Press</a></li></ul></div><div class="footer-block"><h6>More</h6><ul><li><a href="https://app.adjust.com/gh97ibu?redirect=https://itunes.apple.com/app/id296581815?mt=8" target="_blank">OpenTable for iOS</a></li><li><a href="https://app.adjust.com/dk33pts?redirect=https://play.google.com/store/apps/details?id=com.opentable" target="_blank">OpenTable for Android</a></li><li><a onclick="onLinkClick('https://dev.opentable.com')">Affiliate Program</a></li><li><a onclick="onLinkClick('https://help.opentable.com/s/?language=en_US')">Contact Us</a></li></ul></div><div class="footer-block"><h6>Our Sites</h6><ul><li></li><li><a href="https://www.opentable.jp">OpenTable.jp</a></li><li><a href="https://www.opentable.de">OpenTable.de</a></li><li><a href="https://www.opentable.es">OpenTable.es</a></li><li><a href="https://www.opentable.com.mx">OpenTable.com.mx</a></li><li><a href="https://www.opentable.ca">OpenTable.ca</a></li><li><a href="https://www.opentable.hk">OpenTable.hk</a></li><li><a href="https://www.opentable.ie">OpenTable.ie</a></li><li><a href="https://www.opentable.sg">OpenTable.sg</a></li><li><a href="https://www.opentable.nl">OpenTable.nl</a></li><li><a href="https://www.opentable.co.uk">OpenTable.co.uk</a></li><li><a href="https://www.opentable.com.au">OpenTable.com.au</a></li><li><a href="https://www.opentable.ae">OpenTable.ae</a></li><li><a href="https://www.opentable.co.th">OpenTable.co.th</a></li><li><a href="https://www.opentable.it">OpenTable.it</a></li></ul></div><div class="footer-block"><h6>Restaurateurs</h6><a class="button small with-arrow text-arrow-right" onclick="onLinkClick('https://restaurant.opentable.com/?utm_source=dinersite&amp;utm_medium=referral&amp;utm_campaign=topnav&amp;Lead.LeadSource=DinerSite&amp;Lead.Marketing_ID__c=topnav')">Delight more diners</a><a class="button small with-arrow text-arrow-right" onclick="onLinkClick('https://openforbusiness.opentable.com')">Open for Business Blog</a><h6>Join us on</h6><div class="footer-social-links"><a class="footer-link-social" onclick="onLinkClick('https://twitter.com/opentable')" title="twitter"><svg height="24px" version="1.1" viewbox="0 0 24 24" width="24px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
# <g class="social-icon-cutout" fill="#D8D8D8" transform="translate(-67.000000, -79.000000)">
# <path d="M79,103 C72.372583,103 67,97.627417 67,91 C67,84.372583 72.372583,79 79,79 C85.627417,79 91,84.372583 91,91 C91,97.627417 85.627417,103 79,103 Z M76.40272,97.375 C81.68576,97.375 84.57536,92.9983565 84.57536,89.202951 C84.57536,89.07864 84.57536,88.954889 84.56696,88.8316979 C85.1291056,88.4251173 85.6143591,87.9216961 86,87.3450054 C85.4757723,87.5772776 84.9196644,87.7296016 84.35024,87.7968927 C84.9498566,87.4379486 85.3986292,86.8733918 85.61304,86.2082876 C85.0492082,86.5428384 84.4323618,86.7786131 83.78912,86.9054372 C82.8987664,85.9587664 81.4840028,85.7270654 80.3381476,86.3402588 C79.1922923,86.9534522 78.600314,88.2590417 78.
202.8716,96.4569021 C202.544858,96.3299176 202.311674,96.1782308 202.066735,95.9332647 C201.821797,95.6883263 201.670082,95.4551416 201.543098,95.1283996 C201.447234,94.8817385 201.333198,94.5110938 201.302077,93.8286007 C201.2684,93.0904789 201.261259,92.8690758 201.261259,91.0000139 C201.261259,89.1309242 201.2684,88.9095211 201.302077,88.1713993 C201.333198,87.4889062 201.447234,87.1182615 201.543098,86.8716004 C201.670082,86.5448584 201.821769,86.3116737 202.066735,86.0667353 C202.311674,85.8217692 202.544858,85.6700824 202.8716,85.5430979 C203.118262,85.4472343 203.488906,85.3331984 204.171399,85.3020774 C204.909521,85.2684002 205.130924,85.261259 207.000014,85.261259 Z M207.000014,93.3333333 C205.71133,93.3333333 204.666667,92.2886704 204.666667,91.0000139 C204.666667,89.7113296 205.71133,88.6666667 207.000014,88.6666667 C208.28867,88.6666667 209.333333,89.7113296 209.333333,91.0000139 C209.333333,92.2886704 208.28867,93.3333333 207.000014,93.3333333 Z M207.000014,87.4054077 C205.014749,87.4054077 203.405408,89.0147487 203.405408,91.0000139 C203.405408,92.9852513 205.014749,94.5945923 207.000014,94.5945923 C208.985251,94.5945923 210.594592,92.9852513 210.594592,91.0000139 C210.594592,89.0147487 208.985251,87.4054077 207.000014,87.4054077 Z M211.576624,87.2633906 C211.576624,86.7994665 211.200534,86.4233756 210.736609,86.4233756 C210.272713,86.4233756 209.896622,86.79 ...
# </g>
# </g>
# </svg><img alt="instagram" class="hide"/></a></div></div></div><div class="footer-content-container"><div class="footer-base"><a class="footer-base-link" href="/legal/privacy-policy">Privacy Policy</a><a class="footer-base-link" href="/legal/terms-and-conditions">Terms of Use</a><a class="footer-base-link" href="/legal/cookie-policy">Cookies and Interest-Based Ads</a><a class="footer-base-link" id="teconsent" style="display: none;"></a><br/><span class="footer-copyright">Copyright © 2019 OpenTable, Inc. 1 Montgomery St Ste 700, San Francisco CA 94104 - All rights reserved.</span></div><div class="footer-base ot-affiliates"><span>OpenTable is part of Booking Holdings, the world leader in online travel and related services.</span><br/><div class="priceline-links"><div class="affiliate-logo logo-booking"></div><div class="affiliate-logo logo-priceline"></div><div class="affiliate-logo logo-kayak"></div><div class="affiliate-logo logo-agodo"></div><div class="affiliate-logo logo-rentalcars"></div><div class="affiliate-logo logo-opentable"></div></div></div></div></div></div><div id="truste_banners"><div id="consent_blackbar"></div></div><script>window.OT = window.OT || {};
# window.OT.SRS = window.OT.SRS || {};
# var onLinkClick = function(url) {
#   window.open(url, '_blank');
# }</script><script async="async" crossorigin="localhost" src="//consent.truste.com/notice?domain=opentable.com&amp;c=teconsent&amp;js=bb&amp;noticeType=bb&amp;text=true"></script><script>window.oc=window.oc||{};oc.renderedComponents=oc.renderedComponents||{};oc.renderedComponents["footer"]="1.0.121";</script><div class="global-footer-system-info"> (Build Version:0.2.900) (Machine Name:prod-sc mesos-slave236-prod-sc.otsql.opentable.com) (Request ID:8f6e80ec-787c-4bf2-a880-7ff39bd56b62)</div><script>
"SearchQuery":null,"ShowMap":false,"Size":25,"Sort":"Name","SortString":"Name","Tags":null,"Tests":null,"TimeslotSort":"pop","Title":null,"Topic":null},"Display":{"Availability":"on","CoverOptions":[{"IsSelected":false,"Text":"1 person","Value":1},{"IsSelected":true,"Text":"2 people","Value":2},{"IsSelected":false,"Text":"3 people","Value":3},{"IsSelected":false,"Text":"4 people","Value":4},{"IsSelected":false,"Text":"5 people","Value":5},{"IsSelected":false,"Text":"6 people","Value":6},{"IsSelected":false,"Text":"7 people","Value":7},{"IsSelected":false,"Text":"8 people","Value":8},{"IsSelected":false,"Text":"9 people","Value":9},{"IsSelected":false,"Text":"10 people","Value":10},{"IsSelected":false,"Text":"11 people","Value":11},{"IsSelected":false,"Text":"12 people","Value":12},{"IsSelected":false,"Text":"13 people","Value":13},{"IsSelected":false,"Text":"14 people","Value":14},{"IsSelected":false,"Text":"15 people","Value":15},{"IsSelected":false,"Text":"16 people","Value":16},{"IsSelected":false,"Text":"17 people","Value":17},{"IsSelected":false,"Text":"18 people","Value":18},{"IsSelected":false, ...
# </script> </div>
# <div class="hamburger-pane" id="hamburger-pane"><div class="hamburger-pane__header"><div class="top-bar show-for-medium-up"><ul class="hamburger-menu"><li class="top-bar-nav-li"></li><a class="top-bar-nav-link js-toggle-hamburger" data-target="hamburger-pane" href="#"><i class="icon-list font-size-medium"></i></a></ul></div><div class="tab-bar hide-for-medium-up"><ul class="hamburger-menu"><li class="top-bar-nav-li"></li><a class="top-bar-nav-link js-toggle-hamburger" data-target="hamburger-pane" href="#"><i class="icon-list font-size-medium"></i></a></ul></div></div><div class="hamburger-pane__body"><ul class="hide-for-medium-up"><a class="menu-list-link menu-list-link-primary" href="/my/registerpopup?rp=https%3A%2F%2Fwww.opentable.com%2Fs%2F%3FmetroId%3D9%26enableSimpleCuisines%3Dtrue%26covers%3D2%26dateTime%3D2019-10-12%252019%253A00%26availability%3DincludeListings%26userlongitude%3D103.86%26userlatitude%3D1.29%26pageType%3D2&amp;srs=1" id="mobile_nav_sign_up" title="Sign up">Sign up</a><a class="menu-list-link menu-list-link-primary" href="/my/loginpopup?rp=https%3A%2F%2Fwww.opentable.com%2Fs%2F%3FmetroId%3D9%26enableSimpleCuisines%3Dtrue%26covers%3D2%26dateTime%3D2019-10-12%252019%253A00%26availability%3DincludeListings%26userlongitude%3D103.86%26userlatitude%3D1.29%26pageType%3D2&amp;srs=1" id="mobile_nav_sign_in" title="Sign in">Sign in</a></ul><div class="languageSelectorLink"><a href="#"><div class="languageSelectorIcon"><div class="iconLanguageSelector"></div></div><div class="languageSelectorLabel">Language</div></a></div><div class="language-selector"><a class="language-selector__link" href="#"><div class="language-icon"><div class="iconLanguageSelector"></div></div></a><div class="language-selector__menu menu menu-right"><div class="menu-container"><div class="menu-main"><div class="menu-section"><div class="language-selector__menu__list menu-list-selectors"><a class="js-languages-list__link menu-list-link" data-lang="de" href="https://www.opentable.com/start/home/?lang=de">Deutsch</a><a aria-selected="true" class="js-languages-list__link menu-list-link selected" data-lang="en" href="https://www.opentable.com/start/home/?lang=en">English</a><a class="js-languages-list__link menu-list-link" data-lang="es" href="https://www.opentable.com/start/home/?lang=es">Español</a><a class="js-languages-list__link menu-list-link" data-lang="fr" href="https://www.opentable.com/start/home/?lang=fr">Français</a><a class="js-languages-list__link menu-list-link" data-lang="it" href="https://www.opentable.com/start/home/?lang=it">Italiano</a><a class="js-languages-list__link menu-list-link" data-lang="nl" href="https://www.opentable.com/start/home/?lang=nl">Nederlands</a><a class="js-languages-list__link menu-list-link" data-lang="ja" href="https://www.opentable.com/start/home/?lang=ja">日本語</a></div></div></div></div></div></div><a class="menu-list-link" href="https://help.opentable.com" target="_blank">Help</a><a class="menu-list-link app-link" href="https://app.adjust.com/d8fpn6m?redirect=https://itunes.apple.com/app/id296581815?mt=8" target="_blank">iOS App</a><a class="menu-list-link app-link" href="https://app.adjust.com/cok1xmg?redirect=https://play.google.com/store/apps/details?id=com.opentable" target="_blank">Android App</a></div></div>
# <div class="hamburger-pane__header"><div class="top-bar show-for-medium-up"><ul class="hamburger-menu"><li class="top-bar-nav-li"></li><a class="top-bar-nav-link js-toggle-hamburger" data-target="hamburger-pane" href="#"><i class="icon-list font-size-medium"></i></a></ul></div><div class="tab-bar hide-for-medium-up"><ul class="hamburger-menu"><li class="top-bar-nav-li"></li><a class="top-bar-nav-link js-toggle-hamburger" data-target="hamburger-pane" href="#"><i class="icon-list font-size-medium"></i></a></ul></div></div>
# <div class="top-bar show-for-medium-up"><ul class="hamburger-menu"><li class="top-bar-nav-li"></li><a class="top-bar-nav-link js-toggle-hamburger" data-target="hamburger-pane" href="#"><i class="icon-list font-size-medium"></i></a></ul></div>
# <div class="tab-bar hide-for-medium-up"><ul class="hamburger-menu"><li class="top-bar-nav-li"></li><a class="top-bar-nav-link js-toggle-hamburger" data-target="hamburger-pane" href="#"><i class="icon-list font-size-medium"></i></a></ul></div>
# <div class="hamburger-pane__body"><ul class="hide-for-medium-up"><a class="menu-list-link menu-list-link-primary" href="/my/registerpopup?rp=https%3A%2F%2Fwww.opentable.com%2Fs%2F%3FmetroId%3D9%26enableSimpleCuisines%3Dtrue%26covers%3D2%26dateTime%3D2019-10-12%252019%253A00%26availability%3DincludeListings%26userlongitude%3D103.86%26userlatitude%3D1.29%26pageType%3D2&amp;srs=1" id="mobile_nav_sign_up" title="Sign up">Sign up</a><a class="menu-list-link menu-list-link-primary" href="/my/loginpopup?rp=https%3A%2F%2Fwww.opentable.com%2Fs%2F%3FmetroId%3D9%26enableSimpleCuisines%3Dtrue%26covers%3D2%26dateTime%3D2019-10-12%252019%253A00%26availability%3DincludeListings%26userlongitude%3D103.86%26userlatitude%3D1.29%26pageType%3D2&amp;srs=1" id="mobile_nav_sign_in" title="Sign in">Sign in</a></ul><div class="languageSelectorLink"><a href="#"><div class="languageSelectorIcon"><div class="iconLanguageSelector"></div></div><div class="languageSelectorLabel">Language</div></a></div><div class="language-selector"><a class="language-selector__link" href="#"><div class="language-icon"><div class="iconLanguageSelector"></div></div></a><div class="language-selector__menu menu menu-right"><div class="menu-container"><div class="menu-main"><div class="menu-section"><div class="language-selector__menu__list menu-list-selectors"><a class="js-languages-list__link menu-list-link" data-lang="de" href="https://www.opentable.com/start/home/?lang=de">Deutsch</a><a aria-selected="true" class="js-languages-list__link menu-list-link selected" data-lang="en" href="https://www.opentable.com/start/home/?lang=en">English</a><a class="js-languages-list__link menu-list-link" data-lang="es" href="https://www.opentable.com/start/home/?lang=es">Español</a><a class="js-languages-list__link menu-list-link" data-lang="fr" href="https://www.opentable.com/start/home/?lang=fr">Français</a><a class="js-languages-list__link menu-list-link" data-lang="it" href="https://www.opentable.com/start/home/?lang=it">Italiano</a><a class="js-languages-list__link menu-list-link" data-lang="nl" href="https://www.opentable.com/start/home/?lang=nl">Nederlands</a><a class="js-languages-list__link menu-list-link" data-lang="ja" href="https://www.opentable.com/start/home/?lang=ja">日本語</a></div></div></div></div></div></div><a class="menu-list-link" href="https://help.opentable.com" target="_blank">Help</a><a class="menu-list-link app-link" href="https://app.adjust.com/d8fpn6m?redirect=https://itunes.apple.com/app/id296581815?mt=8" target="_blank">iOS App</a><a class="menu-list-link app-link" href="https://app.adjust.com/cok1xmg?redirect=https://play.google.com/store/apps/details?id=com.opentable" target="_blank">Android App</a></div>
# <div class="languageSelectorLink"><a href="#"><div class="languageSelectorIcon"><div class="iconLanguageSelector"></div></div><div class="languageSelectorLabel">Language</div></a></div>
# <div class="languageSelectorIcon"><div class="iconLanguageSelector"></div></div>
# <div class="iconLanguageSelector"></div>
# <div class="languageSelectorLabel">Language</div>
# ...
# <div class="rest-row with-image"> <div class="rest-row-image"> <a href="undefined" onclick="OT.BestAnalytics.logRestaurantVisit(7784)" target="_blank"><img alt="photo of agloe bar &amp; grill restaurant" class="lazy rest-image" data-src="//resizer.otstatic.com/v2/profiles/legacy/7784.jpg" src="//media.otstatic.com/search-result-node/images/no-image.png"/></a></div> <div class="rest-row-info"><div class="rest-row-header"> <a class="rest-row-name rest-name" href="undefined" onclick="OT.BestAnalytics.logRestaurantVisit(7784)" target="_blank"><span class="rest-row-name-text">Agloe Bar &amp; Grill</span> </a> </div> <div class="flex-row-justify"> <div class="rest-row-review"> <div class="review-container"> Reviews coming soon</div> </div> <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div> </div><div class="rest-row-meta rest-row-meta-grid flex-row-justify"> <span class="rest-row-meta--cuisine rest-row-meta-text">Sushi</span> <span class="rest-row-meta--location rest-row-meta-text">Murrayfurt</span></div> <div class="message-alerts"> </div> <div class="rest-row-times-cont"><div class="rest-row-times"><div class="timeslot-window"><ul class="availability-row-container"> <li class="timeslot-option timeslot-control"> <a class="rest-row-times-btn timeslot" data-covers="undefined" data-datetime="08/Fr/2015 09:15:48" data-name="Agloe Bar &amp; Grill" data-rid="7784" href="/book/validate?rid=7784&amp;d=08/Fr/2015 09:15:48&amp;p=undefined&amp;pt=100&amp;ss=0&amp;sd=08/Fr/2015 09:15:48&amp;pofids=&amp;hash=&amp;corrid=bb6abfa6-d946-46e8-afe9-3c9379c3b886" onclick="OT.BestAnalytics.
="rest-row-times-btn timeslot" data-covers="undefined" data-datetime="08/Fr/2015 15:15:48" data-name="Agloe Bar &amp; Grill" data-rid="7784" href="/book/validate?rid=7784&amp;d=08/Fr/2015 15:15:48&amp;p=undefined&amp;pt=100&amp;ss=0&amp;sd=08/Fr/2015 15:15:48&amp;pofids=&amp;hash=&amp;corrid=bb6abfa6-d946-46e8-afe9-3c9379c3b886" onclick="OT.BestAnalytics.logRestaurantVisit(7784, '15:15:48')"> <span>7:30</span> </a> </li> <li class="timeslot-option timeslot-empty"></li><li class="timeslot-option timeslot-empty"></li> </ul></div></div>
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# I still don't see it. Let's search our entire soup object:

# %%
# print out soup, do command+f for "booked ". 
#   Uncomment the below to run.

soup
# Out:
#  <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="IE=9; IE=8; IE=7; IE=EDGE" http-equiv="X-UA-Compatible"/> <title>Restaurant Reservation Availability</title> <meta content="noindex,nofollow" name="robots"/> <link href="//components.otstatic.com/components/favicon/1.0.6/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/><link href="//components.otstatic.com/components/favicon/1.0.6/favicon/favicon-16.png" rel="icon" sizes="16x16"/><link href="//components.otstatic.com/components/favicon/1.0.6/favicon/favicon-32.png" rel="icon" sizes="32x32"/><link href="//components.otstatic.com/components/favicon/1.0.6/favicon/favicon-48.png" rel="icon" sizes="48x48"/><link href="//components.otstatic.com/components/favicon/1.0.6/favicon/favicon-64.png" rel="icon" sizes="64x64"/><link href="//components.otstatic.com/components/favicon/1.0.6/favicon/favicon-128.png" rel="icon" sizes="128x128"/><link href="//components.otstatic.com/components/favicon/1.0.6/favicon/apple-touch-icon-152x152-precomposed.png" rel="apple-touch-icon-precomposed" sizes="152x152"/><link href="//components.otstatic.com/components/favicon/1.0.6/favicon/apple-touch-icon-144x144-precomposed.png" rel="apple-touch-icon-precomposed" sizes="144x144"/><link href="//components.otstatic.com/components/favicon/1.0.6/favicon/apple-touch-icon-120x120-precomposed.png" rel="apple-touch-icon-precomposed" sizes="120x120"/><link href="//components.otstatic.com/components/favicon/1.0.6/favicon/apple-touch-icon-114x114-precomposed.png" rel="apple-touch-icon-precomposed" sizes="114x114"/><link href="//components.otstatic.com/components/favicon/1.0.6/favicon/apple-touch-icon-76x76-precomposed.png" rel="apple-touch-icon-precomposed" sizes="76x76"/><link href="//components.otstatic.com/components/favicon/1.0.6/favicon/apple-touch-icon-72x72-precomposed.png" rel="apple-touch-icon-precomposed" sizes="72x72"/><link href="//components.otstatic.com/components/favicon/1.0.6/favicon/apple-touch-icon-144x144-precomposed.png" rel="apple-touch-icon-precomposed"/><script>window.oc=window.oc||{};oc.renderedComponents=oc.renderedComponents||{};oc.renderedComponents["favicon"]="1.0.6";</script><meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/> <link href="//media.otstatic.com/search-result-node/css/ot-kit.2a4c448e.css" rel="stylesheet"/>
# <script>
#       window.OTDataLayer = [{"domain":1,"language":"en-US","metro_id":201,"page_name":"multisearchresultpage","user_type":"anonymous","visitor_status":"Logged Out"}];
#     </script>
# <script>window.OT = window.OT || {};
# window.OT.SRS = {
#   abTestingAnalytics: {"account":"2d65a94551a4a1caddd5a825a88698a89e19f2d5","hostname":"ac.opentable.com"},
#   disableRaven: false,
#   domainId: 1,
#   jsHeadVersion: "1.0.90",
#   lang: "en",
#   ocUrl: window.location.protocol + '//oc-registry.opentable.com/v2/',
#   requestId: "8f6e80ec-787c-4bf2-a880-7ff39bd56b62"
# };
#
# window.OT.searchAutoComplete = {};
# window.OT.searchAutoComplete.ticketedRids = [681,1537,3334,7055,11065,29995,47119,53716,89905,100033,112846,114886,118765,140968,160504,185560,185773,210868,211918,212878,233239,252232,263128,267508,268867,270751,335149,347206,349942,984418,986635,986725];
#
# window.oc = window.oc || {};
# window.oc.conf = { globalParameters: { __ot_conservedHeaders: 'x2YPvT6POzqVVB9+77Ms1J0okfVgclGlUvMsRThNTKYNqKNPktFRNUtf8tWbbXwTMsWfbUnWGUBusPpVWLkxERsWJDtHjnhJ2mNaHz3xYT+DyUEMbw5EW+TC74AeMPeJg4OuCK7xDRo8puLgdJlSLcyUExMBmIP8cGEsr60Zp910YI8X0ZfNBx/b1jPQRK+DaWrQ69K1708=' }};
# </script><!--[if lte IE 8]> <script src="//components.otstatic.com/components/js-head/1.0.90/min/ie8_compat.js"></script> <![endif]-->
# <!--[if IE 9]> <script src="//components.otstatic.com/components/js-head/1.0.90/min/ie9_compat.js"></script> <![endif]--><script crossorigin="anonymous" src="//components.otstatic.com/components/js-head/1.0.90/min/bundle_head.js"></script><script>window.oc=window.oc||{};oc.conf=oc.conf||{};oc.conf.templates=(oc.conf.templates||[]).concat([{"type":"oc-template-es6","version":"1.0.1","externals":[]},{"type":"oc-template-jade","version":"6.0.12","externals":[{"global":"jade","url":"https://unpkg.com/jade-legacy@1.11.1/runtime.js","name":"jade"}]},{"type":"oc-template-handlebars","version":"6.0.13","externals":[{"global":"Handlebars","url":"https://unpkg.com/handlebars@4.0.11/dist/handlebars.runtime.min.js","name":"handlebars"}]},{"type":"oc-template-react","version":"2.0.16","externals":[{"global":["Object","assign"],"url":"https://unpkg.com/es6-object-assign@1.1.0/dist/object-assign-auto.min.js","name":"Object.assign"},{"global":"PropTypes","url":"https://unpkg.com/prop-types@15.7.2/prop-types.min.js","name":"prop-types"},{"global":"React","url":"https://unpkg.com/react@16.8.5/umd/react.production.min.js","name":"react"},{"global":"ReactDOM","url":"https://unpkg.com/react-dom@16.8.5/umd/react-dom.production.min.js","name":"react-dom"}]},{"type":"ot-oc-template-react-email","version":"0.0.2","externals":[{"global":"PropTypes","url":"https://unpkg.com/prop-types@15.6.1/prop-types.min.js","name":"prop-types"},{"global":"React","url":"https://unpkg.com/react@16.2.0/umd/react.production.min.js","name":"react"},{"global":"ReactDOM","url":"https://unpkg.com/react-dom@16.2.0/umd/react-dom.production.min.js","name":"react-dom"}]}]);</script><script src="//components.otstatic.com/components/oc-client/0.44.11/src/oc-client.min.js" type="text/javascript"></script>
# <!--[if lte IE 9]> <script src="//components.otstatic.com/components/js-head/1.0.90/min/ie_jquery.js"></script> <![endif]--><script>window.optimizely = window.optimizely || [];</script><script>window.oc=window.oc||{};oc.renderedComponents=oc.renderedComponents||{};oc.renderedComponents["js-head"]="1.0.90";</script> <script src="//media.otstatic.com/search-result-node/js/generated/ie_compat.9472b0c6.js"></script>
# </head><body class="search com domain-com list has-results availability-search initial-load platform-unknown device-unknown page-type-0 appendGiftParameters appendRegionDescription appendReviewTerms customGoals disableMarketingForAffiliatePages domainCulture evaluateFilters sfx333 sfx333-1 sfx530 sfx530-2 sfx243 sfx243-2 sfx348 sfx348-1 sfx450 sfx450-1 sfx463 sfx463-1 sfx978 sfx978-1 sfx1267 sfx1267-1 sfx1149 sfx1149-1 genericExperiment listEvent otRequestId recordRestaurantCount stringifyExplanation userAgent SFX-368 sfx450"><div class="master-container" id="search-master-container"> <script>
#   if (window.Cypress) {
#     window.__TestGaCalls = [];
#     window.MapTrackGA = function(dataPoint) {
#       window.ga = function(_) {
#         window.__TestGaCalls.push(arguments);
#       }
#       var data = {};
#       data[dataPoint] = '1';
#       ga('gtm1.send', 'event', 'map_event', 'map_event', data);
#     }
#   }
#   else {
#     window.MapTrackGA = function(dataPoint) {
#       if (typeof ga === 'function') {
#         var data = {};
#         data[dataPoint] = '1';
#         ga('gtm1.send', 'event', 'map_event', 'map_event', data);
#       }
#     }
#   }
# </script> <style>.icon-font{font-family:icons;speak:none;font-style:normal;font-weight:400;font-variant:normal;text-transform:none;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.breadcrumb li.icon-visible a:before{font-family:icons;speak:none;font-style:normal;font-weight:400;font-variant:normal;text-transform:none;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.breadcrumb{background-color:#fff!important;height:2rem;line-height:1.9rem;font-size:.75rem;border-top:1px solid rgba(0,0,0,.08)!important;border-bottom:none!important;padding:0 1.25rem}.breadcrumb:after,.breadcrumb:before{content:" ";display:table}.breadcrumb:after{clear:both}@media only screen and (min-width:64.0625em){.breadcrumb{padding:0 2.25rem}}.breadcrumb li{position:relative;display:block;float:left;margin:0 1rem 0 .35rem}.breadcrumb li.hidden{display:none}@media only screen and (min-width:40.0625em){.breadcrumb li.hidden{display:block}}.breadcrumb li.icon-visible{margin-left:0;height:100%;width:1.25rem}@media only screen and (min-width:40.0625em){.breadcrumb li.icon-visible{margin-left:.35rem;width:auto}}.breadcrumb li.icon-visible a{display:block;width:100%;height:100%}.breadcrumb li.icon-visible a span{display:none}@media only screen and (min-width:40.0625em){.breadcrumb li.icon-visible a span{display:block}}.breadcrumb li.icon-visible a:before{content:"a";display:block;width:1.5rem;height:2rem;line-height:2rem;text-align:center;position:absolute;font-size:1rem}@media only screen and (min-width:40.0625em){.breadcrumb li.icon-visible a:before{display:none}}.breadcrumb li:first-child{margin-left:0}.breadcrumb li:last-child{margin-right:0}.breadcrumb li:last-child:after,.breadcrumb li:last-child:before{display:none}.breadcrumb li:after,.breadcrumb li:before{content:'';position:absolute;left:100%;margin-left:.25rem}.breadcrumb li:before{top:-1px;border-top:1rem solid transparent;border-bottom:1rem solid transparent;border-left:.6rem solid rgba(0,0,0,.2)}.breadcrumb li:after{top:0;border-top:.96rem solid transparent;border-bottom:.96rem solid transparent;border-left:.56rem solid #fff}.domain-comau .top-bar-nav-link.icon-location{line-height:55px}.domain-comau .top-bar-nav-link.icon-location:before{color:rgba(0,0,0,.12);font-size:18px;position:relative;top:4px;left:-2px}.domain-comau .with-location-picker .tab-bar-logo{margin-left:48px}.domain-comau .hamburger-menu .top-bar-nav-link{line-height:50px}.menu-drawer-left.sliding-menu .menu-close:after{font-family:icons;speak:none;font-style:normal;font-weight:400;font-variant:normal;text-transform:none;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.menu-drawer-left.sliding-menu{position:fixed;background-color:unset;top:0;left:0;width:100%;height:100%;pointer-events:none;transition:background-color .25s ease-out}.menu-drawer-left.sliding-menu.menu-opened{background-color:rgba(0,0,0,.5);pointer-events:auto}.menu-drawer-left.sliding-menu.menu-opened:before{content:none}.menu-drawer-left.sliding-menu.menu-opened .menu-container{transform:translate3d(0,0,0)}.menu-drawer-left.sliding-menu .menu-container{width:220px;height:100%;max-height:initial;transition:transform .5s ease-out;transform:translate3d(-220px,0,0);opacity:1}.menu-drawer-left.sliding-menu .menu-container .menu-main{border-radius:0;box-shadow:none;width:100%;height:100%;margin:0;padding:3rem 0 .25rem 0}.menu-drawer-left.sliding-menu .menu-list-link{transition:color .15s ease-out;font-size:.875rem;padding:.5rem 1rem .5rem 1.5rem}.menu-drawer-left.sliding-menu .menu-list-link-primary{color:#60b2d0!important;border-bottom:1px solid rgba(0,0,0,.08);font-size:1rem;padding:.75rem 1rem .75rem 1.5rem}.menu-drawer-left.sliding-menu .menu-list-link-primary:hover{color:#356273!important}.menu-drawer-left.sliding-menu .menu-list-link-primary.sign-out-link{color:#da3743!important}.menu-drawer-left.sliding-menu .menu-list-link-primary.sign-out-link:hover{color:#8115 ...
# </script><script>window.abtestGoalTracked = {};
# window.displaySearchFormHeader = false
# window.trackGoal = function trackGoal(goalName) {
#   if(window.analytics) {
#     if (window.debug_abtest_tracking) { console.log('Tracking goal: ', goalName); }
#
#     window.analytics.track(
#       'track_goal',
#       { goal_name: goalName },
#       function (err) { if(err) console.log(err); }
#     );
#   }
# };
#
# window.trackGoalOnce = function trackGoalOnce(goalName) {
#   if (!window.abtestGoalTracked[goalName]) {
#     window.abtestGoalTracked[goalName] = true;
#     window.trackGoal(goalName);
#   }
# }
#
# window.pageData = window.pageData || {};
# window.pageData.serialisedMetros = [{"n":"Atlanta / Georgia","d":"Atlanta / Georgia","m":16,"cn":"United States","cid":"US","did":1,"l":"en","u":"/atlanta-restaurants","r":6275,"lat":33.80692,"lon":-84.32424,"ma":[{"n":"Atlanta","m":50,"u":"/i/atlanta/atlanta-restaurants","r":2301},{"n":"Alpharetta / Roswell","m":199,"u":"/g/atlanta/alpharetta-roswell-restaurants","r":363},{"n":"Northeast Atlanta","m":1012,"u":"/g/atlanta/northeast-atlanta-restaurants","r":901},{"n":"South Atlanta","m":1015,"u":"/g/atlanta/south-atlanta-restaurants","r":556},{"n":"
lat":41.8779,"lon":-87.852445,"ma":[{"n":"Chicago","m":11,"u":"/i/chicago/chicago-restaurants","r":3098},{"n":"North Suburbs","m":12,"u":"/g/chicago/north-suburbs-restaurants","r":917},{"n":"West Suburbs","m":15,"u":"/g/chicago/west-suburbs-restaurants","r":1204},{"n":"Northwest Suburbs","m":107,"u":"/g/chicago/northwest-suburbs-restaurants","r":1108},{"n":"Southwest Suburbs","m":198,"u":"/g/chicago/southwest-suburbs-restaurants","r":749},{"n":"Near West","m":1429,"u":"/g/chicago/near-west-restaurants","r":323},{"n":"South Suburbs","m":13,"u":" ...
# window.pageData.metroId = 9;
# window.pageData.words = {
#   all: 'All {0}',
#   table: '',
#   usernameWelcome: 'Hello!'
# };
# window.pageData.headerSignedIn = false;
# window.forRestaurateursLink = {
#   onClick: function forRestaurateursLinkClicked() {
#     var url = 'https://restaurant.opentable.com/?utm_source=dinersite&utm_medium=referral&utm_campaign=topnav&Lead.LeadSource=DinerSite&Lead.Marketing_ID__c=topnav';
#     window.trackGoal('header_forRestaurateursLink_click');
#     window.open(url, '_blank');
#   }
# };
# window.promoBanner = {
#   onClick: function promoBannerClicked() {
#     var url = 'https://www.opentable.co.uk/promo.aspx?m=72&ref=18212&pid=11316';
#     window.trackGoal('header_londonRestaurantFestivalBanner_click');
#     window.open(url, '_blank');
#   }
# }
# </script><script>$(".breadcrumb-link").click(function(c){window.trackGoal&&window.trackGoal("breadcrumb_link_clicked")});</script><img alt="" height="0" src="https://tag.yieldoptimizer.com/ps/ps?t=i&amp;p=5816&amp;uex=D1ED25A9-053B-4477-B4E1-EC9C0C144CA9" style="display: none;" width="0"/><script>window.oc=window.oc||{};oc.renderedComponents=oc.renderedComponents||{};oc.renderedComponents["header"]="1.4.120";</script> <div class="" id="search_control_container"> <div class="labels cf" id="search_control"> <div class="page-header cf"><div class="max-width-wrapper"><div class="page-header-content"> <div class="row"><div class="column"> <oc-component data-hash="fff6ca51de789e4cc6a7f6cbc1989fcd212dc14e" data-name="dtp" data-rendered="true" data-version="1.8.7" href="https://oc-registry.opentable.com/v2/dtp/^1.6.1?twoBoxSearch=false&amp;dateTime=2019-10-12T19%3A00&amp;metroId=9&amp;partySize=2&amp;showLargerParty=true&amp;showSearch=true&amp;searchPlaceholder=Location%2C%20Restaurant%2C%20or%20Cuisine&amp;theme=com&amp;showLoader=false&amp;spotlightButton=false&amp;otKit=false&amp;eventPrefix=&amp;renderCypressDataAttributes=false"><link href="//components.otstatic.com/components/dtp/1.8.7/dist/style.css" rel="stylesheet"/><style>@media (min--moz-device-pixel-ratio: 1.5), (-o-min-device-pixel-ratio: 3 / 2), (-webkit-min-device-pixel-ratio: 1.5), (min-device-pixel-ratio: 1.5), (min-resolution: 144dpi), (min-resolution: 1.5dppx) {
#     .tt-dropdown-menu:before {
#         background-image: url('//components.otstatic.com/components/dtp/1.8.7/img/menu-arrow@2x.png') !important;
#         background-size: 100%;
#     }
# }
# </style><div class="dtp-picker hide dtp-lang-en with-search single-search" data-event-prefix="" id="dtp-picker-114"><form class="dtp-picker-form false"><input name="timezoneOffset" title="timezoneOffset" type="hidden" value="-240"/><select class="party-size-picker hide"><option value="1">1 person</option><option selected="selected" value="2">2 people</option><option value="3">3 people</option><option value="4">4 people</option><option value="5">5 people</option><option value="6">6 people</option><option value="7">7 people</option><option value="8">8 people</option><option value="9">9 people</option><option value="10">10 people</option><option value="11">11 people</option><option value="12">12 people</option><option value="13">13 people</option><option value="14">14 people</option><option value="15">15 people</option><option value="16">16 people</option><option value="17">17 people</option><option value="18">18 people</option><option value="19">19 people</option><option value="20">20 people</option><option value="21">Larger party</option></select><input class="date-picker dtp-picker-selector" title="datePicker" type="text" value="2019-10-12"/><select class="time-picker hide"><option value="00:00">12:00 AM</option><option value="00:30">12:30 AM</option><option value="01:00">1:00 AM</option><option value="01:30">1:30 AM</option><option value="02:00">2:00 AM</option><option value="02:30">2:30 AM</option><option value="03:00">3:00 AM</option><option value="03:30">3:30 AM</option><option value="04:00">4:00 AM</option><option value="04:30">4:30 AM</option><option value="05:00">5:00 AM</option><option value="05:30">5:30 AM</option><option value="06:00">6:00 AM</option><option value="06:30">6:30 AM</option><option value="07:00">7:00 AM</option><option value="07:30">7:30 AM</option><option value="08:00">8:00 AM</option><option value="08:30">8:30 AM</option><option value="09:00">9:00 AM</option><option value="09:30">9:30 AM</option><option value="10:00">10:00 AM</option><option value="10:30">10:30 AM</option><option value="11:00">11:00 AM</option><option value="11:30">11:30 AM</option><option value="12:00">12:00 PM</option><option value="12:30">12:30 PM</option><option value="13:00">1:00 PM</option><option value="13:30">1:30 PM</option><option value="14:00">2:00 PM</option><option value="14:30">2:30 PM</option><option value="15:00">3:00 PM</option><option value="15:30">3:30 PM</option><option value="16:00">4:00 PM</option><option value="16:30">4:30 PM</option><option value="17:00">5:00 PM</option><option value="17:30">5:30 PM</option><option value="18:00">6:00 PM</option><option value="18:30">6:30 PM</option><option selected="selected" value="19:00">7:00 PM</option><option value="19:30">7:30 PM</option><option value="20:00">8:00 PM</option><option value="20:30">8:30 PM</option><option value="21:00">9:00 PM</option><option value="21:30">9:30 PM</option><option value="22:00">10:00 PM</option><option value="22:30">10:30 PM</option><option value="23:00">11:00 PM</option><option value="23:30">11:30 PM</option></select><div class="dtp-picker-search-container"><div class="dtp-picker-search-icon icon-search"></div><input class="dtp-picker-search" id="dtp-search-single-box" name="searchText" placeholder="Location, Restaurant, or Cuisine" title="Location, Restaurant, or Cuisine" type="text" value=""/></div><input class="button dtp-picker-button" type="submit" value="Find a Table"/></form><script>window.OT = window.OT || {};
# window.dtp_data = { theme: 'com', lang: 'en', ocUrl: 'na-srs.opentable.com/v2/', allowYesterday: false};
# </script><script src="//components.otstatic.com/components/dtp/1.8.7/dist/dtp.js?dtpId=dtp-picker-114"></script></div><script>window.oc=window.oc||{};oc.renderedComponents=oc.renderedComponents||{};oc.renderedComponents["dtp"]="1.8.7";</script></oc-component></div></div></div></div></div></div></div> <div class="modal-container table-categories-overlay" id="table-categories-overlay"><div class="modal-close"></div><div class="modal-content"><div class="modal-content-body table-selector"><div class="content-block table-selector-content" data-select-translation="Select" data-unavailable-translation="Unavailable"><div class="table-selector-header"><h3>Please select a table type</h3></div><div class="category-rows"> <div class="category-row" data-category="default" data-standard-category="true"><div class="left category-name"> Standard</div> <a class="right button category-button" data-href-addon="&amp;st=Standard&amp;papa=&amp;tc=default" href="" target="_blank">Select</a></div> <div class="category-row" data-category="bar" data-standard-category="false"><div class="left category-name"> Bar</div> <a class="right button category-button" data-href-addon="&amp;st=Standard&amp;papa=&amp;tc=bar" href="" target="_blank">Select</a></div> <div class="category-row" data-category="counter" data-standard-category="false"><div class="left category-name"> Counter</div> <a class="right button category-button" data-href-addon="&amp;st=Standard&amp;papa=&amp;tc=counter" href="" target="_blank">Select</a></div> <div class="category-row" data-category="hightop" data-standard-category="false"><div class="left category-name"> High Top</div> <a class="right button category-button" data-href-addon="&amp;st=Standard&amp;papa=&amp;tc=highTop" href="" target="_blank">Select</a></div> <div class="category-row" data-category="outdoor" data-standard-category="false"><div class="left category-name"> Outdoor</div> <a class="right button category-button" data-href-addon="&amp;st=Standard&amp;papa=&amp;tc=outdoor" href="" target="_blank">Select</a></div> </div></div></div></div></div> <input id="_csrf" name="_csrf" type="hidden" value="Jcte5Hv7-BmV6xVci_3UgnoCzwiRUyhKyzH4"/><div class="overall-search-container" id="no-re-render-container"> <div class="filters-bar show-filter-content" id="filters-bar"><div class="max-width-wrapper js-sticky-target" id="sticker"><div class="row"><div class="column"><div class="visual_map_icon" data-view="map" role="button" tabindex="0"><div class="visual-button button"> Map</div></div> <div aria-label="filters" id="search_filters" role="search"> <ul class="filters-list"> </ul> </div></div></div></div></div> <div class="stack-selected-filters"> <div class="toggle-filter-bar"><div id="filter-toggle"><div class="filter-toggle-icon"></div> <span class="show-filter-text">Show filters</span> <span class="hide-filter-text">Hide filters</span></div></div><div class="selected-filters js-selected-filters full-width-wrapper"><div class="row"><div class="column" id="js-selected-filters-column"></div></div></div> <div aria-label="search results" class="search-results-container page-main-content max-width-wrapper" id="search_results_container" role="main"><div class="close-filters"></div> <div class="loader" id="loading_animation"><div class="spinner"></div><div aria-live="assertive" class="loader-content" id="loading_error_container"></div><span aria-live="assertive" id="loading_message" style="opacity: 0"></span></div> <div class="results-set results-table search-results" data-name="ResultsTable" id="search_results"> <div class="content-section-header"> <div class="flex-row-justify results-header"> <h3 class="results-title color-dark" id="results-title">  100 Restaurants </h3> <div class="sort-view-filters"><div class="filter-option right filter-option-sort-orders" id="sort-filters"> <label class="sort-dropdown" data-target="sort-filter-menu" id="js-sort-dropdown"><div class="sort-dropdown__container"> <input class="sort-dropdown__checkbox" i ...
#   //TODO: Integrate this into react component during rewrite.  It toggles the .rest-row-offer-link from
#   // functionally expanding to see all offers, hiding the p.rest-row-offer-link and showing
#   // a.rest-row-offer-link which changes text from "See all specials" to "Learn More >" and links to the
#   // specials section on rest profile. Ticket: https://opentable.atlassian.net/browse/SV-2558
#   $('p.rest-row-offer-link').on('click', function(event) {
#     event.preventDefault();
#     $(this).closest('.hide-more-offers').removeClass('hide-more-offers').addClass('show-more-offers');
#   });
# </script> </div><div class="results-set results-map search-results" data-name="ResultsMap" id="search_results_map"> </div> <div id="row-service-results"></div></div></div><div class="right-sidebar" id="right-sidebar"></div></div> <style>.footer-base .affiliate-logo.logo-kayak{width:91px!important}.footer-base .priceline-links{margin-top:16px}#truste_banners{position:fixed;bottom:0;width:100%;max-width:100rem;display:flex;flex-direction:column-reverse;z-index:999}#truste_banners #truste-consent-track{position:static;bottom:auto}#truste-consent-content .truste-button2,#truste-consent-content .truste-messageColumn,#truste-consent-content2 .truste-messageColumn2,#truste-consent-content2 .truste-please-note{font-family:source-sans-pro,"Source Sans Pro","Helvetica Neue",Helvetica,Arial,sans-serif}#truste-consent-content .truste-button2{display:inline-block;width:auto}#truste-consent-track,#truste-consent-track2{background:rgba(51,51,51,.95)!important;z-index:999}#truste-consent-content .truste-buttonsColumn{margin:0}#truste-consent-content .truste-messageColumn{margin:23px 0}@media screen and (min-width:1025px){#truste-consent-content .truste-messageColumn{margin:23px 15px}}.footer-link-social{float:left;margin-right:8px;margin-bottom:8px;height:24px}@media screen and (min-width:641px) and (max-width:1024px){.footer-link-social{margin-right:4px;margin-bottom:4px}}.footer-link-social svg{width:24px;height:24px}.footer-link-social .social-icon-cutout{fill:#acacac}.footer-link-social:hover .social-icon-cutout{fill:#fff}.footer-link-social:last-child{margin-right:0}.footer-block a{cursor:pointer}</style><style>.footer-base .affiliate-logo {
#   background-image: url(//components.otstatic.com/components/footer/1.0.121/img/affiliate_logos.png) !important;
# }
# </style><div class="footer-container" id="footer" role="contentinfo"><div class="max-width-wrapper"><div class="email-signup footer-content-container"></div><script>$(function(){
#   $('.email-signup').html(oc.build({
#     baseUrl: OT.SRS.ocUrl,
#     name: 'oc_component_email_signup',
#     parameters: { language: 'en-US', metroId: '9' }
#   }));
#
#   oc.renderUnloadedComponents();
# });</script><div class="footer-content-container"><div class="footer-block"><h6>Discover</h6><ul><li><a onclick="onLinkClick('https://help.opentable.com/s/article/OpenTable-Dining-Rewards?language=en_US')">Dining Rewards</a></li><li><a href="https://www.opentable.com/m/private-dining-restaurants-in-north-america/">Private Dining</a></li><li><a href="https://www.opentable.com/m/best-restaurants-in-america-for-2017/">Top 100 Restaurants</a></li><li></li><li><a onclick="onLinkClick('https://help.opentable.com/s/article/How-do-I-make-reservations-for-others-with-an-Administrative-Professional-Account-1505261764797?language=en_US')">Reserve for Others</a></li><li><a onclick="onLinkClick('https://opentable.com/nearme/all-cuisines-near-me')">Cuisines Near Me</a></li></ul></div><div class="footer-block"><h6>OpenTable</h6><ul><li><a href="https://www.opentable.com/about/">About Us</a></li><li><a onclick="onLinkClick('https://blog.opentable.com')">Blog</a></li><li><a href="https://www.opentable.com/careers/">Careers</a></li><li><a onclick="onLinkClick('http://press.opentable.com')">Press</a></li></ul></div><div class="footer-block"><h6>More</h6><ul><li><a href="https://app.adjust.com/gh97ibu?redirect=https://itunes.apple.com/app/id296581815?mt=8" target="_blank">OpenTable for iOS</a></li><li><a href="https://app.adjust.com/dk33pts?redirect=
584 201.821769,86.3116737 202.066735,86.0667353 C202.311674,85.8217692 202.544858,85.6700824 202.8716,85.5430979 C203.118262,85.4472343 203.488906,85.3331984 204.171399,85.3020774 C204.909521,85.2684002 205.130924,85.261259 207.000014,85.261259 Z M207.000014,93.3333333 C205.71133,93.3333333 204.666667,92.2886704 204.666667,91.0000139 C204.666667,89.7113296 205.71133,88.6666667 207.000014,88.6666667 C208.28867,88.6666667 209.333333,89.7113296 209.333333,91.0000139 C209.333333,92.2886704 208.28867,93.3333333 207.000014,93.3333333 Z M207.000014,87.4054077 C205.014749,87.4054077 203.405408,89.0147487 203.405408,91.0000139 C203.405408,92.9852513 205.014749,94.5945923 207.000014,94.5945923 C208.985251,94.5945923 210.594592,92.9852513 210.594592,91.0000139 C210.594592,89.0147487 208.985251,87.4054077 207.000014,87.4054077 Z M211.576624,87.2633906 C211.576624,86.7994665 211.200534,86.4233756 210.736609,86.4233756 C210.272713,86.4233756 209.896622,86.79 ...
# </g>
# </g>
# </svg><img alt="instagram" class="hide"/></a></div></div></div><div class="footer-content-container"><div class="footer-base"><a class="footer-base-link" href="/legal/privacy-policy">Privacy Policy</a><a class="footer-base-link" href="/legal/terms-and-conditions">Terms of Use</a><a class="footer-base-link" href="/legal/cookie-policy">Cookies and Interest-Based Ads</a><a class="footer-base-link" id="teconsent" style="display: none;"></a><br/><span class="footer-copyright">Copyright © 2019 OpenTable, Inc. 1 Montgomery St Ste 700, San Francisco CA 94104 - All rights reserved.</span></div><div class="footer-base ot-affiliates"><span>OpenTable is part of Booking Holdings, the world leader in online travel and related services.</span><br/><div class="priceline-links"><div class="affiliate-logo logo-booking"></div><div class="affiliate-logo logo-priceline"></div><div class="affiliate-logo logo-kayak"></div><div class="affiliate-logo logo-agodo"></div><div class="affiliate-logo logo-rentalcars"></div><div class="affiliate-logo logo-opentable"></div></div></div></div></div></div><div id="truste_banners"><div id="consent_blackbar"></div></div><script>window.OT = window.OT || {};
# window.OT.SRS = window.OT.SRS || {};
# var onLinkClick = function(url) {
#   window.open(url, '_blank');
# }</script><script async="async" crossorigin="localhost" src="//consent.truste.com/notice?domain=opentable.com&amp;c=teconsent&amp;js=bb&amp;noticeType=bb&amp;text=true"></script><script>window.oc=window.oc||{};oc.renderedComponents=oc.renderedComponents||{};oc.renderedComponents["footer"]="1.0.121";</script><div class="global-footer-system-info"> (Build Version:0.2.900) (Machine Name:prod-sc mesos-slave236-prod-sc.otsql.opentable.com) (Request ID:8f6e80ec-787c-4bf2-a880-7ff39bd56b62)</div><script>
#   window.OTSearchData = {"DomainInfo":{"id":1,"TopLevelDomain":"com","DomainID":1,"DefaultMetroId":4},"DomainCulture":{"culture":"en-US","domain":"com","language":"en","isDefaultCulture":true,"defaultMetroId":4,"Culture":"en-US","Domain":"com","Language":"en","addCultureToPath":false},"Environment":"prod-sc","NoResultsAreaList":[{"Type":"Metro","Name":"Atlanta","Metro":{"Id":16}},{"Type":"Region","Name":"Boston","Metro":{"Id":7},"Region":{"Id":47}},{"Type":"Region","Name":"Chicago","Met
elected":false,"Text":"6 people","Value":6},{"IsSelected":false,"Text":"7 people","Value":7},{"IsSelected":false,"Text":"8 people","Value":8},{"IsSelected":false,"Text":"9 people","Value":9},{"IsSelected":false,"Text":"10 people","Value":10},{"IsSelected":false,"Text":"11 people","Value":11},{"IsSelected":false,"Text":"12 people","Value":12},{"IsSelected":false,"Text":"13 people","Value":13},{"IsSelected":false,"Text":"14 people","Value":14},{"IsSelected":false,"Text":"15 people","Value":15},{"IsSelected":false,"Text":"16 people","Value":16},{"IsSelected":false,"Text":"17 people","Value":17},{"IsSelected":false,"Text":"18 people","Value":18},{"IsSelected":false, ...
# </script> </div><div class="tooltip" id="tooltip"></div><div class="modal filters-modal" id="filters_modal"></div> <script>
#   window.Resources={
#     Strings: {"BookedToday":"Booked {0} times today","Calendar_FirstDay":"0","Calendar_Months":"Jan,Feb,Mar,Apr,May,Jun,Jul,Aug,Sep,Oct,Nov,Dec","Calendar_Weekdays":"Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday","Calendar_WeekdaysShort":"S,M,T,W,T,F,S","Currency":"$","DateFormat":"MM/DD/YYYY","DomainName":"OpenTable","DTP_Placeholder_Loading":"Loading results for:","DTP_Placeholder_Info":" {0}, {1}, {2}","GoogleMaps_Region":"us","PriceRange2":"$30 and under","PriceRange3":"$31 to $50","PriceRange4":"$50 and over","Recommended":"{0} Recommend","StarRatingText":"{0} star","StarRatingText_Plural":"{0} stars","TimeFormat":"h:mm a","DistanceUnit":"miles","DistanceUnit_Small":"mi","TimeFormatJS":"h:mm A","RestaurantsString":"Restaurants","DateAddedDateFormat":"MMMM D, YYYY","ReviewerDefaultName":"OpenTable Diner","PromoExpiredFallbackMessage":"[PromoName] has come and gone, but you can still dine at these great restaurants. Visit us next year to view a new restaurant list for [PromoName]. In the meantime, check out our other <a href=\"/start.aspx?m=[MetroID]\">[NumOfRestInMetro] [MetroShortName] restaurants</a> on the Opentable network.","NearbyRestaurants":"Nearby Restaurants","ExactMatch_Booked":"{0} people have booked your top choice today. Book soon!","ExactMatch_Recommend":"{0}% of diners recommend your top match. Book soon!","ExactMatch_Urgency":"Your top match. Book soon!","AccessibilitySelectedTag":"Selected"},
#     Home: {
#       Index: {"MileTitle":"mile","PageTitle":"Restaurant Reservation Availability","ReviewsComingSoon":"Reviews coming soon","SearchLoadingText":"Checking Availability"}
#     },
#     Shared: {
#       Common: {
#         BreadCrumbs: {"HomeNode":"Home","LastNode":"Restaurant availability"},
# ...
#         Strings: {"Button_FindATable":"Find a Table","DateTimePartySizeDateFormat":"ddd, MMMM D","Label_Next":"Next","Label_Previous":"Previous","SearchCoversLargeParty":"Larger Party","SearchCoversMultiple":"{0} people","SearchCoversSingular":"{0} person","SearchLabel_Date":"Date","SearchLabel_DateFormat":"mm/dd/yyyy","SearchLabel_Diners":"Party Size","SearchLabel_InvalidSearchMsg":"You have tried to select a time in the past. Please enter a valid date and time combination.","SearchLabel_Time":"Time"}
#       },
#       Search: {
#         FreeTextSearch: {"Context":"From the {0}","Description":"restaurant description","Menu":"menu","NoResultsMessage":"Sorry, we couldn't find any results for {0}. Try checking your spelling or using less specific keywords.","Reviews":"reviews"},
#         Map: {"Navigation_Next":"Next","Navigation_Previous":"Prev","SearchWithin":"Only search for restaurants within","Title":"Showing nearest {0} restaurants","UserPinTitle":"Drag and drop me to search near a different area"},
#         Results: {"AboveMaxPartySize":"Your party size is larger than this restaurant's limit for online bookings.","BelowMinPartySize":"You have not entered the minimum party size for online bookings at this restaurant.","BlockedDay":"Online bookings are not available on this date at this restaurant.","EarlyCutoff":"Your requested date exceeds the minimum advance booking limit for this restaurant.","FilteredBy":"Filtered By","FilteredBy_Cuisine":"Cuisine","FilteredBy_Location":"Location","FilteredBy_OfferType":"Specials","FilteredBy_PopOnly":"1,000 Pt times","FilteredBy_Price":"Price","NotActive":"Online reservations for now have been suspended. If you would like to make a reservation please contact the restaurant directly.","NotFarEnoughInAdvance":"You must make bookings at least 5 minutes in advance of the time at this restaurant.","NoTimesExist":"No tables are available within 2.5 hours of your request.","Offline":"This restaurant is unable to confirm reservations online at the moment. Therefore, please contact the restaurant directly.","RestoreSearch":"Restore last search","SameDayCutoff":"This Restaurant has a cut off time for same day reservations and this has now passed.","SeeAllOffers":"See all specials","TooFarInAdvance":"Your requested date exceeds the maximum advance booking limit for this restaurant.","BlockedTimesExist":"Please accept our apologies on behalf of {0}. Online bookings are not available on this date at this restaurant.","AltTag":"Photo of {0} Restaurant"},
#         Strings: {"NoSearchResults_MetroLink":"Return to the {0} homepage","NoSearchResults_MetroListLink":"Browse the list of all {0} restaurants","NoSearchResults_NoMatch_Message":"Unfortunately there are no OpenTable restaurants that meet all the criteria you specified.","NoSearchResults_NoMatch_Message_Freetext":"There are no restaurants with availability within 30 miles of your search.","NoSearchResults_NoMatch_Title":"We did not find a match for your search","NoSearchResults_Or":"or","NoSearchResults_OtherSuggestions":"Other suggestions","NoSearchResults_OtherSuggestionsMessage":"Or deselect any checkmarked box under \"Narrow results\" to broaden your search","NoSearchResults_StartOverButton":"Start over","NoSearchResults_UndoLastFilterButton":"Undo my last filter action"},
#         TableCategories: {"ModalTitle":"Please select a table type","TooltipTitle":"Seating Options","DescriptionTitle":"Seating","Select":"Select","Unavailable":"Unavailable","Categories":{"default":"Standard","bar":"Bar","counter":"Counter","hightop":"High Top","outdoor":"Outdoor"}},
#         Tabs: {"List":"List","Map":"Map"}
#       },
#       Redesign: {
#         Filters: {"All_Cuisines":"All Cuisines","All_Locations":"All Locations","All_Offers":"All Specials","All_Prices":"All Prices","All_TableCategories":"All Seating Options","All_Tags":"All Top Rated","Label_Apply":"Apply","Label_Cancel":"Cancel","Label_FilterBy_Cuisine":"Filter by Cuisine","Label_FilterBy_OfferType":"Filter by Points & Specials","Label_FilterBy_Price":"Filter by Price","Label_FilterBy_Range":"Choose a Range","Label_Sort":"Sort","Label_Sort_Distance":"Distance","Label_Sort_Name":"A-Z","Label_Sort_Newest":"Newest","Label_Sort_Popularity":"Best Match","Label_Sort_Popularity_Mobile":"Popular","Label_Sort_Rating":"Highest Rated","Label_Sort_Rating_Mobile":"Rating","Title_Cuisines":"Cuisine","Title_Featured":"Featured","Title_Filters":"Filters","Title_Locations":"Location","Title_Neighborhoods":"Neighborhoods","Title_OfferTypes":"Specials","Title_PopOnly":"1,000 Point Times","Title_Price":"Price","Title_Range":"Range:","Title_RefineYourSearch":"Refine Your Search","Title_Regions":"Regions","Title_TableCategories":"Seating Options","Title_Tags":"Top Rated","Title_Time":"Time"},
#         Strings: {"CopyrightFormat":"Copyright &copy; {0} OpenTable, Inc. All rights reserved.","CurrencySymbol":"$","DefaultReviewerName":"OpenTable Diner","InterimLoader":"Finding tables...","Label_Next":"Next","Label_Previous":"Previous","Label_Sort":"Sort","Label_SortBy":"Sort by","Label_Sort_Name":"A-Z","Label_Sort_Popularity":"Best Match","Label_Sort_Rating":"Highest Rated","Label_TopOffer":"Top special:","LearnMore":"Learn more","Less":"Less","MapFooterLink_Privacy":"Privacy Policy","MapFooterLink_Terms":"Terms of Use","More":"More","PointsText":"+ {0} pts","Recently_Viewed":"Recently viewed","Reserve_Dinner":"Reserve for Dinner","Reserve_Lunch":"Reserve for Lunch","Reserve_Now":"Reserve","SearchPlaceholder":"Location, Restaurant, or Cuisine","SearchPlaceholderNoCuisine":"Location or Restaurant","See_More":"See more","SimilarTo":"Similar to {0}","SorrySimilar":"Sorry, we could not find any similar restaurants for {0} at this time","Tags":"Top rated for ","TimeslotAvailability_Single":"Hurry, we only have 1 timeslot left!","TimeslotAvailability_Multiple":"Hurry, we only have {0} timeslots left!","TimeslotAvailability_Single_2":"You're in luck! We still have 1 timeslot left.","TimeslotAvailability_Multiple_2":"You're in luck! We still have {0} timeslots left.","TimeslotLegend_Offer":"Special","TimeslotLegend_Offers":"Specials"},
#         Results: {"Header_Area":"Neighborhood","Header_Availability":"Availability (click time to reserve)","Header_Cuisine":"Cuisine","Header_Name":"Restaurant Name","Header_Name_Short":"Name","Header_Popularity":"Popularity","Header_Price":"Price","Header_Ratings":"Ratings","ListingsMessage":"Unfortunately, this restaurant is not on the OpenTable reservation network. To see if they take reservations and have availability, you will need to call the restaurant directly or visit their website.","DinerRecommendations":"Diner recommendations","ViewMenuLink":"View Menu","NextAvailableButton":"Find next available","PopTitle":"{0} table with 1,000-Point times available","PopTitle_Plural":"{0} tables with 1,000-Point times available","RequestReservation":"Request Reservation","Review":"Review","Reviews":"{0} review","ReviewsComingSoon":"Reviews coming soon","Reviews_Plural":"{0} reviews","Reviews_Good":"Good","Reviews_Very_Good":"Very Good","Reviews_Excellent":"Excellent","Reviews_Awesome":"Awesome","Reviews_Exceptional":"Exceptional","SeeAllOffers":"See all specials","Timeslot1000Points":"1,000pts","Title_Availability":"{0} table available for {1} on {2}, at {3}","Title_Availability_Plural":"{0} tables available for {1} on {2}, at {3}","Title_Exact_Match":"Exact Match","Title_Promos":"{0} Restaurant","Title_NoAvailability":"Tables with no availability for {1} on {2}, at {3}","Title_NoAvailability_Plural":"Tables with no availability for {1} on {2}, at {3}","Title_Regions_Description":"in {0}","Title_Search_Summary":"You searched for {0} in {1}","WithAvailabilityLink":"{0} additional table available","WithAvailabilityLink_Plural":"{0} additional tables available","Header_Distance":"Distance","FeaturedPopTitle":"Restaurant with 1,000-Point times available","FeaturedPopTitle_Plural":"Restaurants with 1,000-Point times available","Header_Sorted_by":"Sorted by:","IncludeInterspercedAvailabilityLink":"Repeat this search showing omitted results","IncludeInterspercedAvailabilityText":"Some restaurants were not shown as they do not have availability matching your search criteria","About1000PointRestaurants":"About 1,000-Point Restaurants","AboutBonusPointRestaurants":"About Bonus Points","PopTooltipContent1":"Earn rewards fast with Bonus Points. Every time you dine with OpenTable, you earn 100 points. When you dine at <strong>select bonus point restaurants</strong>, you earn 500 or 1,000 points.","PopTooltipContent2":"Since you’re eligible for rewards after 2,000 points, just a few Bonus Point reservations you honor will get you there. Points are redeemable for dining rewards or Amazon gift cards.","Related_Searches":"Related searches","RestaurantsYouMayLike":"Restaurants you may also like","SingleSearchResults":"Search result for {0}","Title_IntersperseAvailability_Plural":"{0} tables for {1} on {2}, at {3}","Title_DateLessSearch":"{0} tables available","Title_DateLessSearch_Singular":"{0} table available","Title_Promos_Plural":"{0} Restaurants","Explanation_BecauseYouLiked":"Because you liked {0}","Explanation_SimilarExperienceTo":"Similar experience to {0}","Explanation_SimilarMenuTo":"Similar menu to {0}","ViewAffiliatedRestaurantsLink":"View affiliated restaurants","Title_Consumer_Disclosure":"How are Featured results ranked","Tooltip_Label_Consumer_Disclosure":"Tooltip info for how search results are ranked","Popover_Consumer_Disclosure":"The default order for search results reflects a number of factors, including table availability, restaurant location, search criteria, and restaurant reviews and ratings. In addition, payment made by a restaurant to OpenTable is also a factor for the relative ordering of restaurants."},
#         NoResults: {"Heading":"We did not find a match for your search","OtherSuggestionsHeading":"Other suggestions","OtherSuggestionsMessage":"Or deselect any checked filters to broaden your search"},
#         PremiumAccess: {"Tables":"Premium Access Tables","CalloutText":"Popular restaurants have set aside tables to offer our most loyal diners. You can book these tables through OpenTable by redeeming your Dining Points.","GotIt":"Got It","LearnMore":"Learn More","BookText":"This premium table has been set aside for loyal diners like you"}
#       },
#       PopRestaurantList: {
#         Strings: {"PageTitleFormat":"{0} restaurants dining rewards","PageDescription":"Earn free meals faster by making a 1,000 point reservation at one of these great restaurants. Once you reach 2,000 points you'll be able to redeem them for a $20 dining cheque!","PopScheduleHeading":"1,000 point tables","SearchBigHeadingFormat":"Make a 1,000-Point Reservation in {0}","PointsAboutText":"Get rewarded for dining.<br />Faster, with 1,000-point tables."}
#       },
#     }
#   };
# </script><script src="//media.otstatic.com/search-result-node/js/generated/bundle_views_redesign.c76eb3d7.js"></script> <script id="marketing-data-layer-scripts">
#     window.OT = window.OT || {};
#     window.OT.MarketingDataLayer = {"language":"en-US","page_name":"search","time_search":"6:20:40 AM","date_search":"2019-10-12T06:20:40+00:00","current_date":"2019-10-12T06:20:40.695Z","day_type":"weekend","searchgeo_longlat":"139.729166,139.729166","logged_in_status":"logged_out","user_primary_metro_id":201,"user_origin":201};
#   </script> <script id="srs-scripts">window.OT = window.OT || {};
# window.OT.SRS = window.OT.SRS || {};
#
# window.OT.SRS.appcuesAccountId = 43830;
# window.OT.SRS.calendarStartsSunday = true;
# window.OT.SRS.dateFormatJS = "mmm d, yyyy";
# window.OT.SRS.disableAppcues = false;
# window.OT.SRS.disableRecaptchaV3 = false;
# window.OT.SRS.disableSignal = false;
# window.OT.SRS.jsVersion = "1.5.21";
# window.OT.SRS.location = "//components.otstatic.com/components/js/1.5.21/";
# window.OT.SRS.recaptchaV3Key = "6Ldcf5gUAAAAANNm2f66Vs0s7G5muVGh9j17Neex";
# window.OT.SRS.secure_domain = "www.opentable.com";
# window.OT.SRS.srsUrl = "//na-srs.opentable.com";
# window.OT.SRS.timeFormatJS = "h:mm A";
# window.OT.SRS.today = "Today";
# window.OT.SRS.tomorrow = "Tomorrow";
# window.OT.SRS.datePickerLocalization = null;
# window.OT.SRS.brightTagSrc = "//srsv2.s3.amazonaws.com/components/js/1.5.21/min/brighttag.html";
# window.abGlobal10Variant = 0;
# window.includeImpressionsFix = true;
# </script><style type="text/css">.grecaptcha-badge {
#   visibility: hidden;
# }
# </style><script crossorigin="anonymous" src="//components.otstatic.com/components/js/1.5.21/min/bundle_common.js"></script><noscript><iframe display="none" height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MJTRF6F" visibility="hidden" width="0"></iframe></noscript><script>window.oc=window.oc||{};oc.renderedComponents=oc.renderedComponents||{};oc.renderedComponents["js"]="1.5.21";</script> <script src="//media.otstatic.com/search-result-node/js/generated/bundle_common_redesign.e9f2fa9c.js"></script>
# <script src="//media.otstatic.com/search-result-node/js/generated/bundle_redesign.96221144.js"></script>
# <script src="//media.otstatic.com/search-result-node/js/generated/commonjs-bundle.7b43543c.js"></script>
# <script src="//media.otstatic.com/search-autocomplete-client/js/one-box-search-14.1.2.min.js"></script>
# <!-- Experiments -->
# <script>
#   /**
#    * Server side logic can be found in:
#    * app/deadCodeDection
#    */
#   function initDeadCodeDetection() {
#     window.openGraves = [];
#     setInterval(function () {
#       if (window.openGraves.length) {
#         // clone array
#         var data = window.openGraves.slice();
#         // empty array.
#         window.openGraves.splice(0);
#
#         var qs = data.map(function(val){ return 'g=' + encodeURIComponent(val); });
#         navigator.sendBeacon('/s/dead-code?' + qs.join('&'));
#
#       }
#     }, 10000)
#     window.tombstone = function tombstong(key) {
#       window.openGraves.push(key);
#     }
#     window.addEventListener("unload", function() {
#       if (window.openGraves.length) {
#         var data = window.openGraves;
#         var qs = data.map(function(val){ return 'g=' + encodeURIComponent(val); });
#         navigator.sendBeacon('/s/dead-code?' + qs.join('&'));
#       }
#     });
#   }
#   initDeadCodeDetection();
#
#   /* Please do not remove this tombstone: */
#   tombstone('x-client');
#
#   OT.Common.init();
#   OT.Redesign.init();
#   OT.Autocomplete.init();
#   OT.BestAnalytics.logRequest();
#   OT.Search.ApplyUserGeoLocation();
# </script>
# <script>
#     OT.Common.Analytics.init(
#       jQuery.extend(
#         {"channel":"Tokyo Metropolitan Area","charSet":"UTF-8","eVar16":"ratingssearchuser","eVar24":"All","eVar28":"09:00:00","eVar30":100,"eVar34":"Logged Out","eVar36":"anonymous","eVar39":"Tokyo Metropolitan Area","eVar41":"MetroDTP","eVar43":"multisearchresultpage","eVar47":"listsearcher","eVar50":"multisearchresultpage","eVar57":"WebRedesign_New","eVar72":"tt_no_offers_searchresults","eVar74":"new_architecture_newdesign","events":"event2,event23","pageName":"multisearchresultpage","prop1":"Tokyo Metropolitan Area:search","prop24":"All","prop25":"2016-10-31T09:00:00","prop28":"09:00:00","prop2":"Tokyo Metropolitan Area:search:multi","prop30":100,"prop33":"All","prop35":"searchopentables","prop38":"multisearchresultpage","prop45":"nofpopshown","prop46":"ratingsdisplayed","prop58":"","prop7":"Logged Out"},
#         { prop54: s_getLoadTime() }
#       )
#     );
#
#     </script></body> </html>

# %% [markdown]
# What do you notice? Why is this happening?

# %%
html =  requests.get('https://santabarbara.craigslist.org/d/apts-housing-for-rent/search/apa')
soup_cl = BeautifulSoup(html.text, 'html.parser')

# %%
results = soup_cl.find_all('p', attrs={'class': 'result-info'})
listings = []
for result in results:
    result_dict = {}
    result_dict['title'] = result.find('a').text
    result_dict['price'] = result.find('span', attrs={'class': 'result-price'}).text
    listings.append(result_dict)

listings
# Out:
# [{'title': '3BR in Peaceful Neighborhood', 'price': '$3700'},
#  {'title': '3BR 2BATHS close to Butterfly beach.', 'price': '$3800'},
#  {'title': '2BR In the Heart of Downtown SB', 'price': '$3500'},
#  {'title': 'Buellton 3bed 2bath', 'price': '$2995'},
#  {'title': '4 beds 3 baths 2,357 sqft home available now', 'price': '$3000'},
#  {'title': 'Adorable 3beds 2baths for rent', 'price': '$4000'},
#  {'title': 'Newly Remodeled 4bed 2bath home for rent', 'price': '$3200'},
#  {'title': 'Newly Renovated 4bed 2bath home', 'price': '$3200'},
#  {'title': 'House for lease ,14 acres for Commercial Cannabis or Horses (Oklahoma',
#   'price': '$5500'},
#  {'title': 'Family Home', 'price': '$4950'},
#  {'title': 'Luminous 1 bedroom 1 bath condo', 'price': '$2200'},
#  {'title': '4 Bed_3 Baths with air conditioning, hardwood floors, walk-in shower',
#   'price': '$596'},
#  {'title': 'Beautiful Cottage 2 blocks to Cottage Hospital/Oak Park',
#   'price': '$3900'},
#  {'title': 'East Beach /2+2 condo/Furnished w/ Private Garage',
#   'price': '$4600'},
#  {'title': 'GUEST HOUSE, PRIVATE & QUIET', 'price': '$2600'},
#  {'title': 'Mountain Views right from your home!', 'price': '$4450'},
#  {'title': 'Mesa Oceanview: 2 Bedroom, Parking, Laundry, Grocery, Downtown, SBCC',
#   'price': '$2500'},
#  {'title': 'Gorgeous Summerland Views!  Remodeled Kitchen and Bathroom!!!',
#   'price': '$1750'},
#  {'title': 'Charming upstairs 2/1 Downtown Apartment', 'price': '$2650'},
#  {'title': '2 Bedroom unit near Bishop Diego High School!', 'price': '$2400'},
#  {'title': 'quiet, private guest house', 'price': '$2300'},
#  {'title': 'Mesa Oceanview: 2 Bedroom, Parking, Laundry, Grocery, Downtown, SBCC',
#   'price': '$2600'},
#  {'title': 'Montecito Newly Renovated House', 'price': '$7200'},
#  {'title': 'Upstairs 1BR/1BA with vaulted ceilings, granite countertops',
#   'price': '$1850'},
#  {'title': '6 min. to beach, 2 bd/1ba, Mesa Apartment, $2,345 month',
#   'price': '$2345'},
#  {'title': '2BR/1BA Cottage close to Santa Barbara Bowl', 'price': '$2500'},
#  {'title': 'Spacious Mesa Home with Panoramic Views', 'price': '$6300'},
#  {'title': 'Top Floor Studio on the Mesa with Ocean and Island Views!',
#   'price': '$1800'},
#  {'title': 'Near Paseo Nuevo', 'price': '$1615'},
#  {'title': "you'll love coming home when you live with us!", 'price': '$4430'},
#  {'title': 'Brand New Sunny One Bedroom with High Ceilings', 'price': '$2400'},
#  {'title': '►►Updated Upstairs 2 Bed/1 Bath Ready for You to Make it Home!◄◄',
#   'price': '$1600'},
#  {'title': 'Large, 2-story Newly Remodeled Mesa Home', 'price': '$5900'},
#  {'title': 'Live in luxury and sit poolside in your new home!',
#   'price': '$4470'},
#  {'title': 'Spacious 2Bedroom/2bath garden apartment on great Mesa location',
#   'price': '$2400'},
#  {'title': 'Spacious 2Bedroom/2bath garden apartment on great Mesa location',
#   'price': '$2400'},
#  {'title': 'Downtown Ventura- 1BR/1BA studio', 'price': '$915'},
#  {'title': '336 North 6th', 'price': '$2400'},
#  {'title': 'Large house with pool, hot tub, sauna and ocean views!',
#   'price': '$7499'},
#  {'title': 'Secluded home in Carpinteria', 'price': '$3950'},
#  {'title': 'Spanish style home w/ gorgeous views of Downtown Santa Barbara!',
#   'price': '$6400'},
#  {'title': 'Beautiful 3/2 Downtown Carpinteria Home!', 'price': '$3700'},
#  {'title': 'Charming Montecito Gem! Two bedroom condo w/ 2-car garage!',
#   'price': '$4000'},
#  {'title': 'Terrific 2 bedroom Mesa Apartment!', 'price': '$2500'},
#  {'title': 'Cute 1 bedroom, 1 bath near Downtown Ventura', 'price': '$745'},
#  {'title': 'Upstairs 1BR/1BA in Laguna Apartments', 'price': '$1995'},
#  {'title': 'Downstairs 1BR+Den/2BA in Beautiful 55+ Community',
#   'price': '$2495'},
#  {'title': 'Upstairs 1BR/1BA with faux wood floors - cats ok!',
#   'price': '$1795'},
#  {'title': '3 Bed 2 Bath Apt.', 'price': '$1410'},
#  {'title': 'Great Location near Downtown!', 'price': '$1795'},
#  {'title': 'BEACH HOUSE/ SPACIOUS 2 STORY', 'price': '$8995'},
#  {'title': 'Large downstairs apartment! 1BR/ 2BA', 'price': '$2495'},
#  {'title': 'Near Santa Barbara Bowl-2BR/1BA', 'price': '$2500'},
#  {'title': 'Near Mission Creek- 1BR/1BA', 'price': '$1995'},
#  {'title': 'An apartment like no other! a/c cooled, keyless entry, Alexa & more',
#   'price': '$4490'},
#  {'title': '$3400 House 3 bdr/1.5 ba, W/D, Yard, Garage', 'price': '$3400'},
#  {'title': 'S.B. Riviera Ocean View Studio, All Utils Paid, Mo to Mo, Avail Now!',
#   'price': '$1795'},
#  {'title': 'Studio on Turnpike', 'price': '$1300'},
#  {'title': '3 bedroom 1 bath near downtown', 'price': '$2950'},
#  {'title': 'Upstairs 1BR/1BA in Ellwood Beach', 'price': '$1750'},
#  {'title': 'Craftsman Home on Riviera - Amazing Views', 'price': '$2350'},
#  {'title': 'Craftsman Home on Riviera - Amazing Views', 'price': '$2350'},
#  {'title': 'California Cottage in Montecito-2 BR, 3 Baths', 'price': '$6500'},
#  {'title': 'Newly Renovated Downtown One Bedroom/One Bath', 'price': '$1895'},
#  {'title': '2BR/1BA close to Downtown Santa Barbara', 'price': '$2195'},
#  {'title': 'Cute 3BR/1.5BA Duplex in Goleta', 'price': '$3195'},
#  {'title': 'Cute 1BR/1BA close to La Cumbre', 'price': '$1750'},
#  {'title': 'Upstairs 1BR/1BA at Villa Flores', 'price': '$1950'},
#  {'title': 'Available Now - Charming 4 bedroom, 2 1/2 bath', 'price': '$2800'},
#  {'title': 'Los Alamos Home', 'price': '$2750'},
#  {'title': 'Amazing view of Aleck Keck park! 2 bedroom/1 bath',
#   'price': '$2495'},
#  {'title': 'Los Alamos Home', 'price': '$2750'},
#  {'title': 'Montecito Furnished One Bedroom Cottage', 'price': '$3400'},
#  {'title': 'Lovely Solvang Home', 'price': '$3500'},
#  {'title': 'Spectacular Panoramic Oceanview Apartment (includes utilities)',
#   'price': '$2100'},
#  {'title': 'Spacious 2BR/1BA Downstairs Apartment near Alice Keck Park',
#   'price': '$2495'},
#  {'title': 'Downstairs 2BR/1BA Corner Unit', 'price': '$2245'},
#  {'title': 'Upstairs 2BR/1BA in Excellent Downtown Location',
#   'price': '$2395'},
#  {'title': 'Townhouse style 1 bedroom, 1 bath', 'price': '$1750'},
#  {'title': 'Classic Montecito Cottage, Bonus Room, 3 Bedroom, 2 Bath',
#   'price': '$5200'},
#  {'title': 'Upstairs 1BR/1BA - walking distance to the Mission',
#   'price': '$1995'},
#  {'title': 'Showing Today!  Historical Victorian Home, 3 Bedrm, 2 Bath',
#   'price': '$3995'},
#  {'title': 'Quiet 2BR+Den/2BA Montecito Home - walking distance to Butterfly Beach',
#   'price': '$6500'},
#  {'title': 'Classic Montecito Cottage and a Detached Updated Guest House',
#   'price': '$6800'},
#  {'title': 'Large Upstairs 1BR/1BA in 55+ Community', 'price': '$1995'},
#  {'title': 'Spacious Upstairs 1BR/1BA close to San Marcos High School',
#   'price': '$1850'},
#  {'title': 'Spacious 1BR/1BA at Villa Flores', 'price': '$1995'},
#  {'title': 'Call this your home today! 2 bedroom 2 bath unlike any other!',
#   'price': '$3100'},
#  {'title': 'NICELY UPDATED 3BD HOUSE IN QUIET SAN ROQUE NEIGHBORHOOD',
#   'price': '$3550'},
#  {'title': 'Townhouse 1BR/1BA with large walk in closet', 'price': '$1750'},
#  {'title': '1 BR/1BA Garden Courtyard', 'price': '$1995'},
#  {'title': 'Beautiful Garden Courtyard- 1BR/1BA', 'price': '$1995'},
#  {'title': '$2250 LARGE COTTAGE DUPLEX', 'price': '$2250'},
#  {'title': 'Fully Furnished Studio', 'price': '$1800'},
#  {'title': 'Fully Furnished Studio', 'price': '$1800'},
#  {'title': 'Spacious Upstairs 1BR/1BA in Great Downtown Location',
#   'price': '$1795'},
#  {'title': 'Bright, balcony, pool, off street parking (tl9d-96)',
#   'price': '$1825'},
#  {'title': 'Renovated Unit Downtown! Plank floors, Quartz Counters, New Appliances',
#   'price': '$3125'},
#  {'title': '2 Bd 1 Bath Westside', 'price': '$3800'},
#  {'title': 'Sunny and Bright 2 Bedroom on the Mesa', 'price': '$2475'},
#  {'title': 'Carriage House 1 Bed Apartment', 'price': '$1425'},
#  {'title': 'Private 2 Bedroom 1 Bath Apartment', 'price': '$2300'},
#  {'title': 'Charming One Bedroom', 'price': '$1875'},
#  {'title': 'Come Live in the Luxurious Lower Village 2 Bedroom Condo',
#   'price': '$3400'},
#  {'title': 'Sunny 4 Bed/2 Bath Home in Goleta with Beautiful & Private Backyard',
#   'price': '$3950'},
#  {'title': 'A home like no other! heat or cool your place from your phone!',
#   'price': '$4470'},
#  {'title': '2 bath-Spacious Apt w/ Wood Beamed Ceilings', 'price': '$2150'},
#  {'title': 'Beautiful Mountain Views, rooftop garden, and much more!!!!!',
#   'price': '$3595'},
#  {'title': 'One Bedroom Duplex Located in Mission Canyon Heights',
#   'price': '$2650'},
#  {'title': 'Spacious, W/T/G incl. balcony, No smoking (ds-20)',
#   'price': '$1780'},
#  {'title': 'Ocean View! Remodeled, upstairs end unit (j6h-d)',
#   'price': '$2450'},
#  {'title': 'Townhouse, patio, 2 prk spaces, newer carpet (hk5p-b)',
#   'price': '$2650'},
#  {'title': 'Spacious, hook ups, patio, yard, sm pet considered (hc0c)',
#   'price': '$4450'},
#  {'title': 'Spacious, near UCSB & Costco, parking, laundry (ge-20)',
#   'price': '$1550'},
#  {'title': 'Townhouse, patio, end unit, near State St, fireplace (p9d-c)',
#   'price': '$2625'},
#  {'title': 'Ocean views, remodeled kitchen & bath, upstairs (j6h-f)',
#   'price': '$2250'},
#  {'title': 'Townhouse condo, patio, pool, W/D, near Patterson Ave (cx0k)',
#   'price': '$2600'},
#  {'title': "Small, cozy, plank floors, near Trader Joe's, w/t/g/e incl. (p5d-5)",
#   'price': '$1295'},
#  {'title': 'Ocean Views!  Balcony, W/T/G included, carport  (f0b-1)',
#   'price': '$2450'},
#  {'title': 'New lighting, spacious, granite, no cosigners or smoking (r6e-8)',
#   'price': '$2350'}]

# %% [markdown]
# <a id="selenium"></a>
# ## Introducing Selenium
#
# Selenium is a headless browser. It allows us to render JavaScript just as a human-navigated browser would.
#
# To install Selenium, use one of the following:
# - **Anaconda:** `conda install -c conda-forge selenium`
# - **pip:** `pip install selenium`
#
# You will also need GeckoDriver (this assumes you are using Homebrew for Mac):
#
# - ```brew install geckodriver```
#
# Additionally, you will need to have downloaded the [Firefox browser](https://www.mozilla.org/en-US/firefox/new/?utm_source=google&utm_medium=cpc&utm_campaign=Firefox-Brand-US-GGL-Exact&utm_term=firefox&utm_content=A144_A203_A006336&gclid=Cj0KEQjwnPLKBRC-j7nt1b7OlZwBEiQAv8lMLJUyReT6cPzSYdmEA6uD3YDoieuuuusddgAU7XH6smEaAoje8P8HAQ&gclsrc=aw.ds) for the application in this lesson.

# %%
# import
from selenium import webdriver

# %% [markdown]
# Selenium requires us to determine a default browser to run. I'm going to opt for Firefox, but Chromium is also a very common choice. http://selenium-python.readthedocs.io/faq.html

# %%
# STOP
# what is going to happen when I run the next cell?

# %%
# create a driver called Chrome
driver = webdriver.Chrome(executable_path="./practice/chromedriver/chromedriver")

# %% [markdown]
# Pretty crazy, right? Let's close that driver.

# %%
# close it
driver.close()

# %%
# let's boot it up, and visit a URL of our choice
driver = webdriver.Chrome(executable_path="./practice/chromedriver/chromedriver")
driver.get("http://www.python.org")

# %%
driver.close()

# %% [markdown]
# Awesome. Now we're getting somewhere: programmatically controlling our browser like a human.

# %% [markdown]
# Let's return to our problem at hand. We need to visit the OpenTable listing for DC. Once there, we need to get the html to load. In the next cell, prove you can programmatically visit the page.

# %%
# visit our OpenTable page
driver = webdriver.Chrome(executable_path="./practice/chromedriver/chromedriver")
driver.get("http://www.opentable.com/washington-dc-restaurant-listings")

# always good to check we've got the page we think we do
assert "OpenTable" in driver.title

# %%
driver.title
# Out:
# 'Washington, D.C. Area Restaurants List | OpenTable'

# %%
driver.close()

# %% [markdown]
# <a id="selenium-js"></a>
# ### Running JavaScript before scraping
#
# Now, to resolve our JavaScript problem, there's a few things we can do. What I'll do in this case is request that the page load, wait one second, and then I'm going to grab the source html from the page. Because the page should believe I'm visiting from a live connection on a browser client, the JavaScript should render to be a part of the page source. I can then grab the page source.

# %%
# import sleep
from time import sleep

# %%
# visit our relevant page
driver = webdriver.Chrome(executable_path="./practice/chromedriver/chromedriver")
driver.get("http://www.opentable.com/washington-dc-restaurant-listings")

# wait one second
sleep(1)

#grab the page source
html = driver.page_source

# %% [markdown]
# **Pop Quiz:** What do we need to do with this HTML?

# %%
# BeautifulSoup it!
html = BeautifulSoup(html, "lxml")

# %% [markdown]
# Now, let's return to our earlier problem: How do we locate bookings on the page?

# %%
# print out the number bookings for all restaurants
html.find_all('div', {'class':'booking'})
# Out:
# [<div class="booking"><span class="tadpole"></span>Booked 31 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 6 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 43 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 43 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 54 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 1 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 107 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 28 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 12 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 46 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 58 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 64 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 33 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 41 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 15 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 40 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 40 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 37 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 113 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 38 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 38 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 29 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 32 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 23 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 10 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 22 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 3 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 22 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 207 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 15 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 30 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 50 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 534 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 61 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 166 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 5 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 63 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 13 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 56 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 56 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 77 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 9 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 24 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 10 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 12 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 28 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 17 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 3 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 11 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 5 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 27 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 37 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 3 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 38 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 15 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 26 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 63 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 49 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 15 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 150 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 73 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 31 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 89 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 74 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 40 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 7 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 58 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 1 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 49 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 3 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 57 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 30 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 71 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 49 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 31 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 33 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 2 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 19 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 35 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 31 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 68 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 70 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 71 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 9 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 44 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 70 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 14 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 38 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 36 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 193 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 112 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 261 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 257 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 79 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 145 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 17 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 23 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 60 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 15 times today</div>]

# %%
# now print out each booking for the listings using a loop
for entry in html.find_all('div', {'class':'booking'}):
    print(entry)
# Out:
# <div class="booking"><span class="tadpole"></span>Booked 31 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 6 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 43 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 43 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 54 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 1 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 107 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 28 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 12 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 46 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 58 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 64 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 33 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 41 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 15 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 40 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 40 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 37 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 113 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 38 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 38 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 29 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 32 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 23 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 10 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 22 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 3 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 22 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 207 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 15 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 30 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 50 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 534 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 61 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 166 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 5 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 63 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 13 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 56 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 56 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 77 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 9 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 24 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 10 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 12 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 28 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 17 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 3 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 11 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 5 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 27 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 37 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 3 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 38 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 15 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 26 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 63 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 49 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 15 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 150 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 73 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 31 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 89 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 74 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 40 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 7 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 58 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 1 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 49 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 3 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 57 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 30 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 71 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 49 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 31 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 33 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 2 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 19 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 35 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 31 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 68 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 70 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 71 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 9 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 44 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 70 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 14 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 38 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 36 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 193 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 112 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 261 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 257 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 79 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 145 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 17 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 23 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 60 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 15 times today</div>

# %% [markdown]
# Let's grab just the text of each of these entries.

# %%
# do the same as above, but grabbing only the text content
for entry in html.find_all('div', {'class':'booking'}):
    print(entry.text)
# Out:
# Booked 31 times today
# Booked 6 times today
# Booked 43 times today
# Booked 43 times today
# Booked 54 times today
# Booked 1 times today
# Booked 107 times today
# Booked 28 times today
# Booked 12 times today
# Booked 46 times today
# Booked 58 times today
# Booked 64 times today
# Booked 33 times today
# Booked 41 times today
# Booked 15 times today
# Booked 40 times today
# Booked 40 times today
# Booked 37 times today
# Booked 113 times today
# Booked 38 times today
# Booked 38 times today
# Booked 29 times today
# Booked 32 times today
# Booked 23 times today
# Booked 10 times today
# Booked 22 times today
# Booked 3 times today
# Booked 22 times today
# Booked 207 times today
# Booked 15 times today
# Booked 30 times today
# Booked 50 times today
# Booked 534 times today
# Booked 61 times today
# Booked 166 times today
# Booked 5 times today
# Booked 63 times today
# Booked 13 times today
# Booked 56 times today
# Booked 56 times today
# Booked 77 times today
# Booked 9 times today
# Booked 24 times today
# Booked 10 times today
# Booked 12 times today
# Booked 28 times today
# Booked 17 times today
# Booked 3 times today
# Booked 11 times today
# Booked 5 times today
# Booked 27 times today
# Booked 37 times today
# Booked 3 times today
# Booked 38 times today
# Booked 15 times today
# Booked 26 times today
# Booked 63 times today
# Booked 49 times today
# Booked 15 times today
# Booked 150 times today
# Booked 73 times today
# Booked 31 times today
# Booked 89 times today
# Booked 74 times today
# Booked 40 times today
# Booked 7 times today
# Booked 58 times today
# Booked 1 times today
# Booked 49 times today
# Booked 3 times today
# Booked 57 times today
# Booked 30 times today
# Booked 71 times today
# Booked 49 times today
# Booked 31 times today
# Booked 33 times today
# Booked 2 times today
# Booked 19 times today
# Booked 35 times today
# Booked 31 times today
# Booked 68 times today
# Booked 70 times today
# Booked 71 times today
# Booked 9 times today
# Booked 44 times today
# Booked 70 times today
# Booked 14 times today
# Booked 38 times today
# Booked 36 times today
# Booked 193 times today
# Booked 112 times today
# Booked 261 times today
# Booked 257 times today
# Booked 79 times today
# Booked 145 times today
# Booked 17 times today
# Booked 23 times today
# Booked 60 times today
# Booked 15 times today

# %%
driver.close()

# %% [markdown]
# We've succeeded!
#
# <a id="selenium-regex"></a>
# ### Using regex to only get digits
#
# But we can clean this up a little bit. We're going to use regular expressions (regex) to grab only the digits that are available in each of the text.
#
# The best way to get good at regex is to, well, just keep trying and testing: http://pythex.org/

# %%
# import regex
import re

# %% [markdown]
# Given we haven't covered regex, I'll show you how to use the search function to match any given digit.

# %%
# for each entry, grab the text
for booking in html.find_all('div', {'class':'booking'}):
    # match all digits
    match = re.search(r'\d+', booking.text)
    
    if match:
        # print if found
        print(match.group())
    else:
        # otherwise pass
        pass
# Out:
# 31
# 6
# 43
# 43
# 54
# 1
# 107
# 28
# 12
# 46
# 58
# 64
# 33
# 41
# 15
# 40
# 40
# 37
# 113
# 38
# 38
# 29
# 32
# 23
# 10
# 22
# 3
# 22
# 207
# 15
# 30
# 50
# 534
# 61
# 166
# 5
# 63
# 13
# 56
# 56
# 77
# 9
# 24
# 10
# 12
# 28
# 17
# 3
# 11
# 5
# 27
# 37
# 3
# 38
# 15
# 26
# 63
# 49
# 15
# 150
# 73
# 31
# 89
# 74
# 40
# 7
# 58
# 1
# 49
# 3
# 57
# 30
# 71
# 49
# 31
# 33
# 2
# 19
# 35
# 31
# 68
# 70
# 71
# 9
# 44
# 70
# 14
# 38
# 36
# 193
# 112
# 261
# 257
# 79
# 145
# 17
# 23
# 60
# 15

# %% [markdown]
# Before we demonstrate all the other amazing things about headless browsers, let's finish up collecting the data we want from this current example. Do you suppose the html parsing we wrote above will still work on the page source we've grabbed from our headless browser?

# %% [markdown]
# To be most efficient, we want to only do a single loop for each entry on the page. That means we want to find what element all of other other elements (name, location, price, bookings) is housed within. Where on the page is each entry located?

# %%
# print out all entries
#   NOTE: Has many entries. Uncomment the below code to run it!

soup.find_all('div', {'class':'result content-section-list-row cf with-times'})
# Out:
# [<div class="result content-section-list-row cf with-times" data-id="0" data-index="1" data-is-marketed="true" data-is-promoted="undefined" data-lat="69.0280" data-lon="-145.1894" data-offers="" data-restaurant-availability-token="" data-rid="18251"><div class="rest-row with-image"> <div class="rest-row-image"> <a href="undefined" onclick="OT.BestAnalytics.logRestaurantVisit(18251)" target="_blank"><img alt="photo of durward ziemann restaurant" class="lazy rest-image" data-src="//resizer.otstatic.com/v2/profiles/legacy/18251.jpg" src="//media.otstatic.com/search-result-node/images/no-image.png"/></a></div> <div class="rest-row-info"><div class="rest-row-header"> <a class="rest-row-name rest-name" href="undefined" onclick="OT.BestAnalytics.logRestaurantVisit(18251)" target="_blank"><span class="rest-row-name-text">Durward Ziemann</span> </a> </div> <div class="flex-row-justify"> <div class="rest-row-review"> <div class="review-container"> Reviews coming soon</div> </div> <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div> </div><div class="rest-row-meta rest-row-meta-grid flex-row-justify"> <span class="rest-row-meta--cuisine rest-row-meta-text">Indonesian</span> <span class="rest-row-meta--location rest-row-meta-text">South Mathew</span></div> <div class="message-alerts"> </div> <div class="rest-row-times-cont"><div class="rest-row-times"><div class="timeslot-window"><ul class="availability-row-container"> <li class="timeslot-option timeslot-control"> <a class="rest-row-times-btn timeslot" data-covers="undefined" data-datetime="08/Fr/2015 09:15:48" data-name="Durward Ziemann" data-rid="18251" href="/book/validate?rid=18251&amp;d=08/Fr/2015 09:15:48&amp;p=undefined&amp;pt=100&amp;ss=0&amp;sd=08/Fr/2015 09:15:48&amp;pofids=&amp;hash=&amp;corrid=bb6abfa6-d946-46e8-afe9-3c9379c3b886" onclick="OT.BestAnalytics.logRestaurantVisit(18251, '09:15:48')"> <span>6:15</span> </a> </li> <li class="timeslot-option time
"><div class="timeslot-window"><ul class="availability-row-container"> <li class="timeslot-option timeslot-control"> <a class="rest-row-times-btn timeslot" data-covers="undefined" data-datetime="08/Fr/2015 09:15:48" data-name="Geoffrey O'Hara" data-rid="26100" href="/book/validate?rid=26100&amp;d=08/Fr/2015 09:15:48&amp;p=undefined&amp;pt=100&amp;ss=0&amp;sd=08/Fr/2015 09:15:48&amp;pofids=&amp;hash=&amp;corrid=bb6abfa6-d946-46e8-afe9-3c9379c3b886" onclick="OT.BestAnalytics.logRestaurantVisit(26100, '09:15:48')"> <span>6:15</span> </a> </li> <li class="timeslot-option timeslot-control"> <a class="rest-row-times-btn timeslot" data-covers="undefined" data-datetime="08/Fr/2015 10:00:48" data-name="Geoffrey O'Hara" data-rid="26100" href="/book/validate?rid=26100&amp;d=08/Fr/2015 10:00:48&amp;p=undefined&amp;pt=100&amp;ss=0&amp;sd=08/Fr/2015 10:00:48&amp;pofids=&amp;hash=&amp;corrid=bb6abfa6-d946-46e8-afe9-3c9379c3b886" onclick="OT.BestAnalytics.logRestaurantVisit(26100, '10:00:48')"> <span>6:30</span> </a> </li> <li class="timeslot-option timeslot-control"> <a class="rest-row-times-btn exact timeslot" data-covers="undefined" data-datetime="08/Fr/2015 11:15:48" data-name="Geoffrey O'Hara" data-rid="26100" href="/book/validate?rid=26100&amp;d=08/Fr/2015 11:15:48&amp;p=undefined&amp;pt=100&amp;ss=0&amp;sd=08/Fr/2015 11:15:48&amp;pofids=&amp;hash=&amp;corrid=bb6abfa6-d946-46e8-afe9-3c9379c3b886" onclick="OT.BestAnalytics.logRestaurantVisit(26100, '11:15:48')"> <span>7:00</span> </a> </li> <li class="timeslot-option timeslot-control"> <a class="rest-row-times-btn timeslot" data-covers="undefined" data-datetime="08/Fr/2015 13:00:48" data-name="Geoffrey O'Hara" data-rid="26100" href="/book/validate?rid=26100&amp;d=08/Fr/2015 13:00:48&amp;p=undefined&amp;pt=100&amp;ss=0&amp;sd=08/Fr/2015 13:00:48&amp;pofids=&amp;hash=&amp;corrid=bb6abfa6-d946-46e8-afe9-3c9379c3b886" onclick="OT.BestAnalytics.logRestaurantVisit(26100, '13:00:48')"> <span>7:15</span> </a> </li> <li class="timeslot-option timeslot-control"> <a class="rest-row-times-btn timeslot" data-covers="undefined" data-datetime="08/Fr/2015 15:15:48" data-name="Geoffrey O'Hara" data-rid="26100" href="/book/validate?rid=26100&amp;d=08/Fr/2015 15:15:48&amp;p=undefined&amp;pt=100&amp;ss=0&amp;sd=08/Fr/2015 15:15:48&amp;pofids=&amp;hash=&amp;corrid=bb6abfa6-d946-46e8-afe9-3c9379c3b886" onclick="OT.BestAnalytics.logRestaurantVisit(26100, '15:15:48')"> <span>7:30</span> </a> </li> <li class="timeslot-option timeslot-empty"></li><li class="timeslot-option timeslot-empty"> ...

# %% [markdown]
# Look over the page. Does every single entry have each element we're seeking?
# > I did this previously. I know for a fact that not every element has a number of recent bookings. That's probably exactly why OpenTable houses this in JavaScript: they want to continously update the number of bookings with the most relevant number of values.

# %%
# We want to only retrieve the text of the bookings.
# But what would happen if we just naively print the text of each node?

for entry in html.find_all('div', {'class':'result content-section-list-row cf with-times'}):
    print(entry.find('div', {'class':'booking'}))   # try adding .text
# Out:
# <div class="booking"><span class="tadpole"></span>Booked 31 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked
# Booked 44 times today
# Booked 70 times today
# Booked 14 times today
# Booked 38 times today
# Booked 36 times today
# Booked 193 times today
# Booked 112 times today
# Booked 261 times today
# Booked 257 times today
# Booked 79 times today
# Booked 145 times today
# Booked 17 times today
# Booked 23 times today
# Booked 60 times today
# ZERO
# Booked 15 times today

# %% [markdown]
# What do you notice takes the place when booking is not found?
#
# We could use exception handling (`try`/`except` blocks) to resolve this. However, exceptions should only be used to handle rare or unexpected errors -- never for normal program flow.
#
# In this case, we expect that some entries will be zero. So, we can just use an `if` statement that tests whether there are any `divs` present; if not, display `'ZERO'`. Here's a demo:

# %%
# if we find the element we want, we print it. Otherwise, we print 'ZERO'
for entry in html.find_all('div', {'class':'result content-section-list-row cf with-times'}):
    booking_tag = entry.find('div', {'class':'booking'})
    
    if booking_tag:
        print(booking_tag.text)
    else:
        print('ZERO')
# Out:
# Booked 31 times today
# Booked 6 times today
# Booked 43 times today
# Booked 43 times today
# Booked 54 times today
# Booked 1 times today
# Booked 107 times today
# Booked 28 times today
# Booked 12 times today
# Booked 46 times today
# Booked 58 times today
# Booked 64 times today
# Booked 33 times today
# Booked 41 times today
# Booked 15 times today
# Booked 40 times today
# Booked 40 times today
# Booked 37 times today
# Booked 113 times today
# Booked 38 times today
# Booked 38 times today
# Booked 29 times today
# Booked 32 times today
# Booked 23 times today
# Booked 10 times today
# Booked 22 times today
# Booked 3 times today
# Booked 22 times today
# Booked 207 times today
# Booked 15 times today
# Booked 30 times today
# Booked 50 times today
# Booked 534 times today
# Booked 61 times today
# Booked 166 times today
# Booked 5 times today
# Booked 63 times today
# Booked 13 times today
# Booked 56 times today
# Booked 56 times today
# Booked 77 times today
# Booked 9 times today
# Booked 24 times today
# Booked 10 times today
# Booked 12 times today
# Booked 28 times today
# Booked 17 times today
# Booked 3 times today
# Booked 11 times today
# Booked 5 times today
# Booked 27 times today
# Booked 37 times today
# Booked 3 times today
# Booked 38 times today
# Booked 15 times today
# Booked 26 times today
# Booked 63 times today
# Booked 49 times today
# Booked 15 times today
# Booked 150 times today
# Booked 73 times today
# Booked 31 times today
# Booked 89 times today
# Booked 74 times today
# Booked 40 times today
# Booked 7 times today
# Booked 58 times today
# Booked 1 times today
# Booked 49 times today
# Booked 3 times today
# Booked 57 times today
# Booked 30 times today
# Booked 71 times today
# Booked 49 times today
# Booked 31 times today
# Booked 33 times today
# Booked 2 times today
# Booked 19 times today
# Booked 35 times today
# Booked 31 times today
# Booked 68 times today
# Booked 70 times today
# Booked 71 times today
# Booked 9 times today
# Booked 44 times today
# Booked 70 times today
# Booked 14 times today
# Booked 38 times today
# Booked 36 times today
# Booked 193 times today
# Booked 112 times today
# Booked 261 times today
# Booked 257 times today
# Booked 79 times today
# Booked 145 times today
# Booked 17 times today
# Booked 23 times today
# Booked 60 times today
# ZERO
# Booked 15 times today

# %% [markdown]
# After previously completing this, we observed that all other elements WILL be returned. This means we do not have to always handle these cases.
#
# <a id="challenge-pandas"></a>
# ### Challenge: Use Pandas to create a DataFrame of bookings
#
# However, the onus is on you to now put all the pieces together.
#
# Loop through each entry. For each entry, grab the relevant information we want (name, location, price, bookings). Produce a dataframe with the columns "name","location","price","bookings" that contains the 100 entries we would like.

# %%
import pandas as pd

# %%
# I'm going to create my empty df first
dc_eats = pd.DataFrame(columns=["name","cuisine","location","price","bookings"])

#don't specify any values

dc_eats
# Out:
# Empty DataFrame
# Columns: [name, cuisine, location, price, bookings]
# Index: []

# %%
for entry in html.find_all('div', {'class':'result content-section-list-row cf with-times'}):
    # grab the name
    name = entry.find('span', {'class':'rest-row-name-text'}).text
    
    # grab the cuisine
    cuisine = entry.find('span', {'class': 'rest-row-meta--cuisine rest-row-meta-text'}).text
    # grab the location
    location = entry.find_all('span', {'class': 'rest-row-meta--cuisine rest-row-meta-text sfx1388addContent'})[1].text
    
    #the [1] is because it returns a list and you want the second element 
    
    # grab the price
    price = entry.find('div', {'class':'rest-row-pricing'}).find('i').text.count('$')
    
    # try to find the number of bookings
    bookings = 'NA'
    booking_tag = entry.find('div', {'class':'booking'})
    if booking_tag:
        match = re.search('\d+', booking_tag.text)
        
        if match:
            bookings = match.group()
    
    dc_eats.loc[len(dc_eats)]=[name, cuisine, location, price, bookings]

# %%
# check out our work
dc_eats.head()
# Out:
#                            name               cuisine             location  \
# 0  Medium Rare - Cleveland Park                 Steak       Cleveland Park
# 1                   Maya Bistro         Mediterranean            Arlington
# 2                     BlackSalt               Seafood  Palisades Northwest
# 3               Bistro Aracosia                Afghan  Palisades Northwest
# 4   El Centro D.F. - Georgetown  Contemporary Mexican           Georgetown
#
#   price bookings
# 0     2       31
# 1     2        6
# 2     3       43
# 3     2       43
# 4     2       54

# %% [markdown]
# Awesome! We succeeded.
#
# <a id="selenium-typing"></a>
# ### Auto-typing using Selenium
#
# Now, let's explore some of the other functionality of a webdriver. We've barely scratched the surface.

# %%
# we can send keys as well
# import
from selenium.webdriver.common.keys import Keys

# %%
# open Firefox
driver = webdriver.Chrome(executable_path="./practice/chromedriver/chromedriver")
# visit Python
driver.get("http://www.python.org")
# verify we're in the right place
assert "Python" in driver.title

# %% [markdown]
# Let's try automatedly typing `pycon` in the search box and hitting the return key:

# %%
# find the search position
elem = driver.find_element_by_name("q")

# clear it
elem.clear()

# type in pycon
elem.send_keys("pycon")

# send those keys
elem.send_keys(Keys.RETURN)

# %%
# close
driver.close()

# %%
# all at once:
driver = webdriver.Chrome(executable_path="./practice/chromedriver/chromedriver")
driver.get("http://www.python.org")
assert "Python" in driver.title

elem = driver.find_element_by_name("q")
elem.clear()
elem.send_keys("pycon")
elem.send_keys(Keys.RETURN)
#assert "No results found." not in driver.page_source
#driver.close()

# %% [markdown]
# The above example (and many others) are available in the Selenium docs: http://selenium-python.readthedocs.io/getting-started.html
#
# What is especially important is exploring functionality like locating elements: http://selenium-python.readthedocs.io/locating-elements.html#locating-elements
#
# FAQ:
# http://selenium-python.readthedocs.io/faq.html

# %% [markdown]
# ### Summary
#
# In this lesson, we used the Beautiful Soup library to locate elements on a website then scrape their text. We also used the Selenium headless browser to run JavaScript first before retrieving the page contents.
