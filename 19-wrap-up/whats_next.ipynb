# %% [markdown]
# # What's Next?
#
# <img src="./assets/whats_next.jpeg" width="720"/>

# %% [markdown]
# ## Foreword

# %% [markdown]
# First, congratulations on completing the 10-week-course!
#
# <img src="./assets/finally.jpg" width="720"/>

# %% [markdown]
# However...
#
# <img src="./assets/journey_begin.jpg" width="720"/>

# %% [markdown]
# Data science education is a lifelong journey...
#
# <img src="./assets/education_lifelong.jpeg" width="720"/>

# %% [markdown]
# ## Where to go from here

# %% [markdown]
# > Revise the lessons, practice makes perfect.
# >
# > Apply them on work or personal project.

# %% [markdown]
# - Continue learning more about Python, Data Science and Machine Learning
#
#   https://www.kaggle.com/learn/overview
#
#
# - Open Data Science Masters Course
#
#   http://datasciencemasters.org/](http://datasciencemasters.org/
#
#
# - Try to automate some of the boring / mundane stuffs away using Python!
#
#   https://automatetheboringstuff.com/

# %% [markdown]
# Or challenge yourself by participating in kaggle competitions / data for social good / data hackathon !
#
# - https://www.kaggle.com/competitions
# - Data Science for good
#     - https://www.dathappy.com/
#     - https://www.meetup.com/DataKind-SG/
# - [Tourism Data Innovation Challenge](https://www.eventbrite.sg/e/data-innovation-for-tourism-registration-74250742971?fbclid=IwAR3fCrw9-kl3w65CmV00QM4NHmhWWcsXEwNVdNxNrD97nvi9a4A8ZpOLjXo)

# %% [markdown]
# ## Future of AI

# %%
from IPython.display import YouTubeVideo, IFrame

# %% [markdown]
# ### NLP

# %% [markdown]
# GPT-2 Text Generator
#
# https://blog.floydhub.com/gpt2/
#
# Demo:
# https://talktotransformer.com/

# %% [markdown]
# Chatbot

# %%
YouTubeVideo("-F6h43DRpcU")

# %%
IFrame("https://www.quantamagazine.org/machines-beat-humans-on-a-reading-test-but-do-they-understand-20191017/?utm_source=aidigest&utm_medium=web&utm_campaign=featured",
       width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="https://www.quantamagazine.org/machines-beat-humans-on-a-reading-test-but-do-they-understand-20191017/?utm_source=aidigest&utm_medium=web&utm_campaign=featured"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Computer Vision

# %% [markdown]
# Object detection

# %%
YouTubeVideo("_kxX09i4fds")

# %%
YouTubeVideo("OOT3UIXZztE")

# %% [markdown]
# Facial Recognition

# %%
YouTubeVideo("lH2gMNrUuEY")

# %%
YouTubeVideo("aE1kA0Jy0Xg")

# %% [markdown]
# ### Generative Adversarial Network

# %% [markdown]
# Style Transfer

# %%
YouTubeVideo("Uxax5EKg0zA")

# %% [markdown]
# Create beautiful image from sketches

# %%
YouTubeVideo("hW1_Sidq3m8")

# %% [markdown]
# Deepfakes

# %%
YouTubeVideo("gLoI9hAX9dw")

# %% [markdown]
# Thank you for being an awesome class!
# <img src="./assets/thank_you.jpg" width="540"/>
#
# My contact details:
#
# > zyuanlim@gmail.com
# >
# > +65 96452700
